# %% [markdown]
# <img style="float: left; margin: 30px 15px 15px 15px;" src="https://pngimage.net/wp-content/uploads/2018/06/logo-iteso-png-5.png" width="300" height="500" />
#
#
# ### <font color='navy'> Simulación de procesos financieros.
#
# **Nombres:** Xareny González,  Estefanía Meza, Alejandra Rico
#
# **Fecha:** 14 de octubre del 2021.
#
# **Expediente** : 720811, 729930, 720838.
#
# **Profesor:** Oscar David Jaramillo Zuluaga.
#
# **Link Github**: [Link con el enlace del repositorio del creador del proyecto](https://github.com/Xarenyglp/ProyectoM1_GonzalezX_MezaE_RicoA)
#
# # Proyecto TEMA 1

# %% [markdown]
# ## 1.1 Análisis de servicio a cliente

# %% [markdown]
# A lo largo de este análisis buscamos brindar un reporte de las métricas que maneja la empresa Tramites APF la cual se dedica a brindar servicios de gestion de Visas, pasaportes y Global Entry. Al finalizar este análisis la empresa podrá tener un panorama más claro de la eficiencia de sus trabajadores y asi lograr llevar a cabo los ajustes necesarios para que de esta manera mejore su servicio a cliente.

# %% [markdown]
# ## 1.2 Objetivos

# %% [markdown]
# ### Objetivo General

# %% [markdown]
# Evaluar de que manera y el tiempo que le toma a los trabajadores realizar cada una de sus actividades analizando metricas previamente proporcionadas por la empresa para que de esta manera ellos puedan optimizar sus recursos

# %% [markdown]
# ### Objetivos Específicos

# %% [markdown]
# - Estimar tiempos de respuesta totales según la categoría de tipo de trámite.
# - Identificar que trámites son los que se llevan a cabo en menor tiempo de acuerdo a cada trabajador
# - Estimar el tiempo invertido en atención al cliente o tiempo invertido por trabajador

# %% [markdown]
# ## 1.3 Definición del problema

# %% [markdown]
# > Tramites APF es una empresa dedicada a la gestión de trámites, por medio de ellos puedes llevar a cabo tu trámite de Visa, pasaporte o Global Entry de inicio a fin sin necesidad de invertir tanto tiempo en estos procesos los cuales resultan ser tediosos y muchas veces confusos. En el último año (durante la pandemia) Tramites APF creció de una manera exponencial. En diciembre 2019 sus clientes por mes eran al rededor de 300 y para finales del 2020 ya eran aproximadamente 2000. De esta manera se han visto en la obligación de mejorar sus procesos para lograr brindar el mejor servicio al cliente ya que es uno de los motivos por los cuales las personas acuden a ellos.
# El plan es claramente continuar creciendo por lo que buscamos ofrecerle a la empresa estimaciones que la apoyen en la toma de decisiones.

# %% [markdown]
# ## 1.4 Nodos y variables que se decidieron simular y porqué

# %% [markdown]
# 1. Estimar los **tiempos totales de solución** según el **número total de visitas**.
#     > El número de visitas y el tiempo de solución son factores de alta importancia, ya que son los que más afectados y se ven en los resultados finales.
#
# 2. Estimar los **tiempos frente al cliente** según su **categoría**.
#     > Dependiendo del tipo de trámite, analizar si éste requiere de más o menos tiempo invertido por el empleado.
#
# 3. Estimar los **tiempos invertidos por servicio** según el **empleado** asignado.
#     > Decidimos escoger estas variables ya que se encuentran relacionadas, el tiempo invertido depende directamente del empleado.
#
# 4. Estimar los **tiempos de respuesta** dependiendo la **ubicación** del trámite.
#     > El tiempo de respuesta es el tiempo que le toma al empleado atender el trámite desde el momento que se contacta, por o que esto depende de la ubicación del cliente.

# %% [markdown]
# <img src="df.jpg">

# %% [markdown]
# ## 1.5 Definición de hipótesis y supuestos

# %% [markdown]
# ### Hipótesis

# %% [markdown]
# Existe una gran correlación entre los nodos que se analizarán por lo que se buscará optimizar los tiempos de la empresa con el fin de disminuir costos y aumentar utilidades.

# %% [markdown]
# ### Supuestos

# %% [markdown]
# - Los tiempos de respuesta excluyen la disponibilidad de citas en cada estado de la republica, o cualquier otra situación externa que pudiera retrasar el trámite.
# - Ignoramos excepciones referentes a cada estado.

# %% [markdown]
# ## 1.6 Obtención de la base de datos

# %% [markdown]
# - **No. Cliente:** número identificador del cliente
# - **Clave AA00:** número que identifica el trámite del cliente
# - **Fecha recepción:** fecha en la que el cliente solicitó el servicio
# - **Estatus:** estatus del trámite
# - **Categoría:** acción a realizar
# - **Ubicación:** estado de la República Mexicana donde se lleva a cabo el trámite
# - **Empleado:** nombre del empleado que atendió la orden de servicio
# - **No. de consultas:** Número de veces que se le contactó al cliente
# - **Fecha cierre:** fecha en la que se concluyó el trámite
# - **T. transcurrido total:** tiempo total que transcurrió desde que se inició el trámite hasta que se finalizó
# - **Tiempo frente al cliente:** tiempo invertido por empleado
# - **T. respuesta:** tiempo que transcurrió desde que el cliente contactó hasta que fue a su cita
# - **Límite T. respuesta:** tiempo máximo acordado para asignación de cita
# - **TST:** tiempo de solución total
# - **Límite TST:** límite de tiempo de solución total
# - **Cerrados el mismo día:** 1 si el tramite se concluyó el mismo dia, 0 si no.
# - **TR OK:** 0 si no se resolvió dentro del límite del tiempo, y 1 si sí se resolvió dentro del límite de tiempo

# %% [markdown]
# ## Funciones a utilizar

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import scipy.stats as st
from sklearn.neighbors import KernelDensity
from scipy.stats import loglaplace 
from scipy.stats.distributions import norm
from sklearn.model_selection import GridSearchCV
from scipy.stats import gaussian_kde
from statsmodels.nonparametric.kernel_density import KDEMultivariate
from statsmodels.nonparametric.kde import KDEUnivariate
import matplotlib
from collections import defaultdict
from time import time
from sklearn.model_selection import GridSearchCV
import statsmodels.api as sm
from IPython.display import Markdown as md
from scipy.stats import cosine
from scipy.stats import logistic
from scipy.stats import dweibull
from scipy.stats import ncf

# %%
def kde_scipy_f(x, bandwidth=0.2, **kwargs):
    """Kernel Density Estimation with Scipy"""
    # Note that scipy weights its bandwidth by the covariance of the
    # input data.  To make the results comparable to the other methods,
    # we divide the bandwidth by the sample standard deviation here.
    kde = gaussian_kde(x, bw_method=bandwidth / x.std(ddof=1), **kwargs)
    return lambda x: kde.evaluate(x)

def kde_sklearn_f(x, bandwidth=0.2, **kwargs):
    """Kernel Density Estimation with Scikit-learn"""
    kde_skl = KernelDensity(bandwidth=bandwidth, **kwargs)
    kde_skl.fit(x[:, np.newaxis])
    # score_samples() returns the log-likelihood of the samples
    log_pdf = lambda x_grid: np.exp(kde_skl.score_samples(x_grid[:, np.newaxis]))
    return log_pdf

def kde_scipy(x, x_grid, bandwidth=0.2, **kwargs):
    """Kernel Density Estimation with Scipy"""
    # Note that scipy weights its bandwidth by the covariance of the
    # input data.  To make the results comparable to the other methods,
    # we divide the bandwidth by the sample standard deviation here.
    kde = gaussian_kde(x, bw_method=bandwidth / x.std(ddof=1), **kwargs)
    return kde.evaluate(x_grid)


def kde_statsmodels_u(x, x_grid, bandwidth=0.2, **kwargs):
    """Univariate Kernel Density Estimation with Statsmodels"""
    kde = KDEUnivariate(x)
    kde.fit(bw=bandwidth, **kwargs)
    return kde.evaluate(x_grid)
    
    
def kde_statsmodels_m(x, x_grid, bandwidth=0.2, **kwargs):
    """Multivariate Kernel Density Estimation with Statsmodels"""
    kde = KDEMultivariate(x, 
                          bw='cv_ml',  #bandwidth * np.ones_like(x),
                          var_type='c', **kwargs)
    return kde.pdf(x_grid)


def kde_sklearn(x, x_grid, bandwidth=0.2, **kwargs):
    """Kernel Density Estimation with Scikit-learn"""
    kde_skl = KernelDensity(bandwidth=bandwidth, **kwargs)
    kde_skl.fit(x[:, np.newaxis])
    # score_samples() returns the log-likelihood of the samples
    log_pdf = kde_skl.score_samples(x_grid[:, np.newaxis])
    return np.exp(log_pdf)


kde_funcs = [kde_statsmodels_u, kde_statsmodels_m, kde_scipy, kde_sklearn]
kde_funcnames = ['Statsmodels-U', 'Statsmodels-M', 'Scipy', 'Scikit-learn']

functions = dict(zip(kde_funcnames, kde_funcs))


def plot_scaling(N=1000, bandwidth=0.1, rtol=0.0,
                 Nreps=3, kwds=None, xgrid=None):
    """
    Plot the time scaling of KDE algorithms.
    Either N, bandwidth, or rtol should be a 1D array.
    """
    if xgrid is None:
        xgrid = np.linspace(-10, 10, 5000)
    if kwds is None:
        kwds=dict()
    for name in functions:
        if name not in kwds:
            kwds[name] = {}
    times = defaultdict(list)
    
    B = np.broadcast(N, bandwidth, rtol)
    assert len(B.shape) == 1
    
    for N_i, bw_i, rtol_i in B:
        x = np.random.normal(size=int(N_i))
        kwds['Scikit-learn']['rtol'] = rtol_i
        for name, func in functions.items():
            t = 0.0
            for i in range(Nreps):
                t0 = time()
                func(x, xgrid, bw_i, **kwds[name])
                t1 = time()
                t += (t1 - t0)
            times[name].append(t / Nreps)
            
    fig, ax = plt.subplots(figsize=(8, 6),
                           subplot_kw={'facecolor':'#EEEEEE',
                                       'axisbelow':True})
    ax.grid(color='white', linestyle='-', linewidth=2)
    plot_kwds={'linewidth':3, 'alpha':0.5}
    
    if np.size(N) > 1:
        for name in kde_funcnames:
            ax.loglog(N, times[name], label=name, **plot_kwds)
        ax.set_xlabel('Number of points')
    elif np.size(bandwidth) > 1:
        for name in kde_funcnames:
            ax.loglog(bandwidth, times[name], label=name, **plot_kwds)
        ax.set_xlabel('Bandwidth')
    elif np.size(rtol) > 1:
        for name in kde_funcnames:
            ax.loglog(rtol, times[name], label=name, **plot_kwds)
        ax.set_xlabel('Relative Tolerance')
        
    for spine in ax.spines.values():
        spine.set_color('#BBBBBB')
    ax.legend(loc=0)
    ax.set_ylabel('time (seconds)')
    ax.set_title('Execution time for KDE '
                 '({0} evaluations)'.format(len(xgrid)))
    
    return times


def plot_scaling_vs_kernel(kernels, N=1000, bandwidth=0.1, rtol=0.0,
                           Nreps=3, kwds=None, xgrid=None):
    """
    Plot the time scaling for Scikit-learn kernels.
    Either N, bandwidth, or rtol should be a 1D array.
    """
    if xgrid is None:
        xgrid = np.linspace(-10, 10, 5000)
    if kwds is None:
        kwds=dict()
    times = defaultdict(list)
    
    B = np.broadcast(N, bandwidth, rtol)
    assert len(B.shape) == 1
    
    for N_i, bw_i, rtol_i in B:
        x = np.random.normal(size=int(N_i))
        for kernel in kernels:
            kwds['kernel'] = kernel
            kwds['rtol'] = rtol_i
            t = 0.0
            for i in range(Nreps):
                t0 = time()
                kde_sklearn(x, xgrid, bw_i, **kwds)
                t1 = time()
                t += (t1 - t0)
            times[kernel].append(t / Nreps)
            
    fig, ax = plt.subplots(figsize=(8, 6),
                           subplot_kw={'facecolor':'#EEEEEE',
                                       'axisbelow':True})
    ax.grid(color='white', linestyle='-', linewidth=2)
    plot_kwds={'linewidth':3, 'alpha':0.5}
    
    if np.size(N) > 1:
        for kernel in kernels:
            ax.loglog(N, times[kernel], label=kernel, **plot_kwds)
        ax.set_xlabel('Number of points')
    elif np.size(bandwidth) > 1:
        for kernel in kernels:
            ax.loglog(bandwidth, times[kernel], label=kernel, **plot_kwds)
        ax.set_xlabel('Bandwidth')
    elif np.size(rtol) > 1:
        for kernel in kernels:
            ax.loglog(rtol, times[kernel], label=kernel, **plot_kwds)
        ax.set_xlabel('Relative Tolerance')
        
    for spine in ax.spines.values():
        spine.set_color('#BBBBBB')
    ax.legend(loc=0)
    ax.set_ylabel('time (seconds)')
    ax.set_title('Execution time for KDE '
                 '({0} evaluations)'.format(len(xgrid)))
    return times


def plot_kernels():
    """Visualize the KDE kernels available in Scikit-learn"""
    fig, ax = plt.subplots(figsize=(8, 6),
                           subplot_kw={'facecolor':'#EEEEEE',
                                       'axisbelow':True})
    ax.grid(color='white', linestyle='-', linewidth=2)
    for spine in ax.spines.values():
        spine.set_color('#BBBBBB')

    X_src = np.zeros((1, 1))
    x_grid = np.linspace(-3, 3, 1000)

    for kernel in ['gaussian', 'tophat', 'epanechnikov',
                   'exponential', 'linear', 'cosine']:
        log_dens = KernelDensity(kernel=kernel).fit(X_src).score_samples(x_grid[:, None])
        ax.plot(x_grid, np.exp(log_dens), lw=3, alpha=0.5, label=kernel)
    ax.set_ylim(0, 1.05)
    ax.set_xlim(-2.9, 2.9)
    ax.legend()
    
    
# Función de aceptación y rechazo usando compresión de listas
def Acep_rechazo(R2:'Variables distruidas U~U(0,1)',
                 R1:'Variables distribuidas como g(x)',
                 f:'función objetivo a generar',
                 t:'función que mayora a f'):
#     R1 = np.random.rand(N)
    f_x = f(R1) #Evalua f en el vector R1
    t_x = t(R1) #Evalua t en el vector R1
    condition = R2*t_x <=f_x
    [plt.plot(R1[i],R2[i]*t_x[i],'ob') if condition[i] else plt.plot(R1[i],R2[i]*t_x[i],'o') \
         for i in range(len(R1))]              
    plt.show()
    
    
# Definimos la función para que nos diga el porcentaje de aceptadas en ambos casos
def histograma(R2:'Variables distruidas U~U(0,1)',
                 R1:'Variables distribuidas como g(x)',
                 f:'función objetivo a generar',
                 t:'función que mayora a f'):
#     R1 = np.random.rand(N)
    f_x = f(R1) #Evalua f en el vector R1
    t_x = t(R1) #Evalua t en el vector R1
    condition = R2*t_x <=f_x
    barras = [R1[i] for i in range(len(R1)) if condition[i]]
    plt.hist(barras,50,density=True)
    plt.xlabel('valores aleatorios')
    plt.ylabel('probabilidad')
    plt.title('histograma función creada')
    plt.show()
    return

# %%
def distribucion(nodo: "Nodo a estudiar", bins: 'bins'):
    '''
    Esta función de devuelve que una gráfica en donde se ve como le quedan distintas distribuciones
    arbitrarias al nodo que el usuario debe ingresar a estudiar, además del orden de menor a menor
    de las distribuciones que se podrán usar más adelante.
    '''
    d_continuas = [d for d in dir(st) if isinstance(getattr(st, d), getattr(st, "rv_continuous"))]

    y, x, _ = plt.hist(nodo, bins=bins, density=True)
    x = x[1:]

    error = pd.DataFrame(columns = ["distribución", "error"])
    i = 0

    for d in d_continuas[10:20]:
        try:
            param = getattr(st, d).fit(nodo)
            y_hat = getattr(st, d).pdf(x,*param)
            error.loc[i, :] = [d, np.mean((y - y_hat)**2)] 
            plt.plot(x, y_hat, label = d)
            i += 1
        except:
            pass
    plt.legend()
    plt.show()

    error.set_index("distribución", inplace=True)
    print(error.sort_values("error"))
    
def prueba_ks(nodo: "Nodo a estudiar"):    
    d_continuas = [d for d in dir(st) if isinstance(getattr(st, d), getattr(st, "rv_continuous"))]
    results = []
    for i in d_continuas[10:20]:
        dist = getattr(st, i)
        param = dist.fit(nodo)
        a = st.kstest(nodo, i, args=param)
        results.append((i,a[0],a[1]))

    results.sort(key=lambda x:float(x[2]), reverse=True)
    for j in results:
        print("{}: statistic={}, pvalue={}".format(j[0], j[1], j[2]))    
    

def qq(nodo: "Nodo a simular", distr:"Distribución a comparar"):
    '''
    Esta función te arroja como se acomoda la distribución elegida (como entrada),
    del nodo introducido.
    '''
    # Histograma de las variables creadas
    divisiones = 20 # Cantidad de barras en el histograma
    fig, ax = plt.subplots(2,1, figsize=(8,10))
    fig.tight_layout(pad=3.0)

    y, x, _ = ax[0].hist(nodo, divisiones, density=True, label='Histograma mediciones')

    # Función de distribución de probabilidad la cual creemos que mis datos distribuyen 
    # RECORDAR: SÓLO FUNCIONA PARA DISTRIBUCIONES CONTINUAS
    dist = distr
    params = getattr(st, dist).fit(nodo)

    # Graficar PDF de la distribución que queremos probar

    # x = np.arange(measurements.min(), measurements.max(), .01)
    y_hat = getattr(st, dist).pdf(x, *params)
    ax[0].plot(x, y_hat,'r--', label='Distribución ajustada')
    ax[0].set_ylabel('Probability')
    ax[0].grid()

    grap1 = sm.qqplot(nodo, dist=getattr(st, dist), line='q', fit=True, ax=ax[1])
    ax[1].grid()
    ax[1].set_title('Usando paquete stats')

# %%
data = pd.read_csv('tramitesapf.csv', encoding='latin1')
data.head()
# Out:
#    No. Cliente  Clave AA00 Fecha recepción   Estatus    Categoría Ubicacion  \
# 0        94830  09HB331426  30/09/20 23:59  RESUELTA           CM   JALISCO
# 1        94829  09HB331586  30/09/20 22:15  RESUELTA  PERSONAL AT   JALISCO
# 2        94828  09HB331608  30/09/20 20:31  RESUELTA  PERSONAL AT   JALISCO
# 3        94827  09HB331507  30/09/20 18:47  RESUELTA  PERSONAL AT   JALISCO
# 4        94826  0Y4X849031  30/09/20 17:03  RESUELTA  PERSONAL AT   JALISCO
#
#                    Empleado  No. Consultas    Fecha cierre  \
# 0  CARLOS GUITIERREZ/800196              1  01/10/20 10:30
# 1       HECTOR MARIN/800207              1  30/09/20 23:10
# 2       HECTOR MARIN/800207              1  30/09/20 11:50
# 3       HECTOR MARIN/800207              1  30/09/20 00:30
# 4       HECTOR MARIN/800207              1  29/09/20 13:10
#
#    T. transcurrido total  Tiempo frente al cliente  T. respuesta  \
# 0              10.500000                  0.500000           0.0
# 1               0.000000                  0.500000           0.0
# 2               0.000000                  0.666667           0.0
# 3               0.666667                  0.666667           0.0
# 4               0.000000                  0.750000           0.0
#
#    Límite T. respuesta  TST  Límite TST  TR OK  Alcance TR  Alcance TST  \
# 0                    5  0.0          48      1         1.0          1.0
# 1                    5  0.0          48      1         1.0          1.0
# 2                    5  0.0          48      1         1.0          1.0
# 3                    5  0.0          48      1         1.0          1.0
# 4                    5  0.0          48      1         1.0          1.0
#
#    Cerrados mismo dia
# 0                   1
# 1                   1
# 2                   1
# 3                   1
# 4                   1

# %%
tiempoT= pd.DataFrame(data,columns=['T. transcurrido total'])
tiempoC= pd.DataFrame(data,columns=['Tiempo frente al cliente'])
tiempoR= pd.DataFrame(data,columns=['T. respuesta'])
TST= pd.DataFrame(data,columns=['TST'])

# Estandarizamos los datos a simular
Tiempos=tiempoT.join(tiempoC).join(tiempoR).join(TST)
Tiempos.head(80)
TST= pd.DataFrame(data,columns=['TST'])
promedio = Tiempos.mean()
des = Tiempos.std()
data_estd = (Tiempos - promedio)/des
data_estd.head(10)
# Out:
#    T. transcurrido total  Tiempo frente al cliente  T. respuesta       TST
# 0              -0.180376                 -0.336437      -0.27994 -0.297862
# 1              -0.332195                 -0.336437      -0.27994 -0.297862
# 2              -0.332195                 -0.228733      -0.27994 -0.297862
# 3              -0.322556                 -0.228733      -0.27994 -0.297862
# 4              -0.332195                 -0.174881      -0.27994 -0.297862
# 5              -0.332195                 -0.228733      -0.27994 -0.297862
# 6              -0.323761                 -0.282585      -0.27994 -0.297862
# 7              -0.332195                 -0.314896      -0.27994 -0.297862
# 8              -0.332195                 -0.336437      -0.27994 -0.297862
# 9              -0.332195                 -0.282585      -0.27994 -0.297862

# %% [markdown]
# # Nodo 1. Tiempos totales de solución

# %%
NV = data.groupby(['Ubicacion']).mean()
prom_TT = NV['T. transcurrido total']
prom_TT.head()
# Out:
# Ubicacion
# AGUASCALIENTES         20.597081
# BAJA CALIFORNIA        52.314035
# BAJA CALIFORNIA SUR    38.760963
# CAMPECHE               90.793478
# CHIAPAS                47.215065
# Name: T. transcurrido total, dtype: float64

# %% [markdown]
# ## Estimación del bandwith adecuado

# %%
x_grid = np.linspace(5, 50, 1000)
x = prom_TT

grid = GridSearchCV(KernelDensity(),
                    {'bandwidth': np.linspace(0.1, 1.0, 30)},
                    cv=20) # 20-fold cross-validation
grid.fit(x[:, None])
print(grid.best_params_)

kde = grid.best_estimator_
pdf = np.exp(kde.score_samples(x_grid[:, None]))

fig, ax = plt.subplots(figsize=(8,6))
ax.plot(x_grid, pdf, linewidth=3, alpha=0.5, label='bw=%.2f' % kde.bandwidth)
ax.hist(x, 30, fc='gray', histtype='stepfilled', alpha=0.3, density=True)
ax.legend(loc='upper right')
ax.set_xlim(5, 50);
# Out:
# {'bandwidth': 1.0}

# %% [markdown]
# ## Método de aceptación y rechazo

# %%
def kde_sklearn(x, x_grid, bandwidth=0.2, **kwargs):
    """Kernel Density Estimation with Scikit-learn"""
    kde_skl = KernelDensity(bandwidth=bandwidth, **kwargs)
    kde_skl.fit(x[:, np.newaxis])
    # score_samples() returns the log-likelihood of the samples
    pdf = lambda x: np.exp(kde_skl.score_samples(x[:, np.newaxis]))
    return pdf

# %%
# Función objetivo 
x_grid = np.linspace(5, 50, 1000)
data1 = np.asarray(prom_TT)
f = kde_sklearn(data1, x_grid, bandwidth=1)
# Máximo de la función f
max_f = max(f(x))
# Función t
t = lambda x: max_f*np.ones(len(x))
x = np.arange(5,50,0.01)  # Rango donde se graficarán las funciones
print('Máximo de f:',max_f) 
# Gráficas de las funciones
plt.figure(figsize=(8,6))

# Validación del método
N = 10000 # número de puntos a simular
R2 = np.random.rand(N)
R1 = np.random.uniform(5,50,N)

Acep_rechazo(R2,R1,f,t);
# Out:
# Máximo de f: 0.05712663185245824

# %%
# Función objetivo 
f = kde_sklearn(data1, x_grid, bandwidth=1)
x = np.arange(5,50,0.01) # Rango donde se graficará las funciones

# Gráfica de la función
plt.figure(figsize=(8,6))
plt.plot(x,f(x),label='f(x)')
plt.legend()

t = lambda x: max_f*np.ones(len(x))
N = 1000
R2 = np.random.rand(N)
R1 = np.random.uniform(5,50,N)
histograma(R2, R1, f, t);

# %% [markdown]
# > El bandwidth óptimo a utilizar es 1.

# %% [markdown]
# ## Ajuste de distribución
#
# > A continuación probaremos distintas distribuciones de probabilidad para nuestros datos, y mediante el error y la prueba de Sminorv-Kolmogrov determinaremos cuál es la que mejor se ajusta a nuestros datos.

# %%
distribucion(prom_TT, 10)
# Out:
# /Users/alerico/opt/anaconda3/lib/python3.8/site-packages/scipy/stats/_continuous_distns.py:2958: RuntimeWarning: The shape parameter of the erlang distribution has been given a non-integer value 1.05.
#   warnings.warn(
# /Users/alerico/opt/anaconda3/lib/python3.8/site-packages/scipy/stats/_continuous_distns.py:2958: RuntimeWarning: The shape parameter of the erlang distribution has been given a non-integer value 1.0333333333333332.
#   warnings.warn(
# /Users/alerico/opt/anaconda3/lib/python3.8/site-packages/scipy/stats/_continuous_distns.py:2958: RuntimeWarning: The shape parameter of the erlang distribution has been given a non-integer value 1.0555555555555554.
#   warnings.warn(
# /Users/alerico/opt/anaconda3/lib/python3.8/site-packages/scipy/stats/_continuous_distns.py:2958: RuntimeWarning: The shape parameter of the erlang distribution has been given a non-integer value 1.083333333333333.
#   warnings.warn(
# /Users/alerico/opt/anaconda3/lib/python3.8/site-packages/scipy/stats/_continuous_distns.py:2958: RuntimeWarning: The shape parameter of the erlang distribution has been given a non-integer value 1.0277777777777775.
#   warnings.warn(
# /Users/alerico/opt/anaconda3/lib/python3.8/site-packages/scipy/stats/_continuous_distns.py:2958: RuntimeWarning: The shape parameter of the erlang distribution has been given a non-integer value 1.0166666666666662.
#   warnings.warn(
# /Users/alerico/opt/anaconda3/lib/python3.8/site-packages/scipy/stats/_continuous_distns.py:2958: RuntimeWarning: The shape parameter of the erlang distribution has been given a non-integer value 1.0333333333333328.
#   warnings.warn(
# /Users/alerico/opt/anaconda3/lib/python3.8/site-packages/scipy/stats/_continuous_distns.py:2958: RuntimeWarning: The shape parameter of the erlang distribution has been given a non-integer value 1.0333333333333323.
#   warnings.warn(
# /Users/alerico/opt/anaconda3/lib/python3.8/site-packages/scipy/stats/_continuous_distns.py:2958: RuntimeWarning: The shape parameter of the erlang distribution has been given a non-integer value 1.0888888888888877.
#   warnings.warn(
# /Users/alerico/opt/anaconda3/lib/python3.8/site-packages/scipy/stats/_continuous_distns.py:2958: RuntimeWarning: The shape parameter of the erlang distribution has been given a non-integer value 1.1333333333333315.
#   warnings.warn(
# /Users/alerico/opt/anaconda3/lib/python3.8/site-packages/scipy/stats/_continuous_distns.py:2958: RuntimeWarning: The shape parameter of the erlang distribution has been given a non-integer value 1.038888888888887.
#   warnings.warn(
# /Users/alerico/opt/anaconda3/lib/python3.8/site-packages/scipy/stats/_continuous_distns.py:2958: RuntimeWarning: The shape parameter of the erlang distribution has been given a non-integer value 1.016666666666664.
#   warnings.warn(
# /Users/alerico/opt/anaconda3/lib/python3.8/site-packages/scipy/stats/_continuous_distns.py:2958: RuntimeWarning: The shape parameter of the erlang distribution has been given a non-integer value 1.1055555555555525.
#   warnings.warn(
# /Users/alerico/opt/anaconda3/lib/python3.8/site-packages/scipy/stats/_continuous_distns.py:2958: RuntimeWarning: The shape parameter of the erlang distribution has been given a non-integer value 1.149999999999996.
#   warnings.warn(
# /Users/alerico/opt/anaconda3/lib/python3.8/site-packages/scipy/stats/_continuous_distns.py:2958: RuntimeWarning: The shape parameter of the erlang distribution has been given a non-integer value 1.166666666666662.
#   warnings.warn(
# /Users/alerico/opt/anaconda3/lib/python3.8/site-packages/scipy/stats/_continuous_distns.py:2958: RuntimeWarning: The shape parameter of the erlang distribution has been given a non-integer value 1.2333333333333272.
#   warnings.warn(
# /Users/alerico/opt/anaconda3/lib/python3.8/site-packages/scipy/stats/_continuous_distns.py:2958: RuntimeWarning: The shape parameter of the erlang distribution has been given a non-integer value 1.1333333333333266.
#   warnings.warn(
# /Users/alerico/opt/anaconda3/lib/python3.8/site-packages/scipy/stats/_continuous_distns.py:2958: RuntimeWarning: The shape parameter of the erlang distribution has been given a non-integer value 1.133333333333324.
#   warnings.warn(
# /Users/alerico/opt/anaconda3/lib/python3.8/site-packages/scipy/stats/_continuous_distns.py:2958: RuntimeWarning: The shape parameter of the erlang distribution has been given a non-integer value 1.3277777777777673.
#   warnings.warn(
# /Users/alerico/opt/anaconda3/lib/python3.8/site-packages/scipy/stats/_continuous_distns.py:2958: RuntimeWarning: The shape parameter of the erlang distribution has been given a non-integer value 1.4833333333333192.
#   warnings.warn(
# /Users/alerico/opt/anaconda3/lib/python3.8/site-packages/scipy/stats/_continuous_distns.py:2958: RuntimeWarning: The shape parameter of the erlang distribution has been given a non-integer value 1.416666666666651.
#   warnings.warn(
# /Users/alerico/opt/anaconda3/lib/python3.8/site-packages/scipy/stats/_continuous_distns.py:2958: RuntimeWarning: The shape parameter of the erlang distribution has been given a non-integer value 1.5499999999999785.
#   warnings.warn(
# /Users/alerico/opt/anaconda3/lib/python3.8/site-packages/scipy/stats/_continuous_distns.py:2958: RuntimeWarning: The shape parameter of the erlang distribution has been given a non-integer value 1.5444444444444207.
#   warnings.warn(
# /Users/alerico/opt/anaconda3/lib/python3.8/site-packages/scipy/stats/_continuous_distns.py:2958: RuntimeWarning: The shape parameter of the erlang distribution has been given a non-integer value 1.6999999999999673.
#   warnings.warn(
# /Users/alerico/opt/anaconda3/lib/python3.8/site-packages/scipy/stats/_continuous_distns.py:2958: RuntimeWarning: The shape parameter of the erlang distribution has been given a non-integer value 2.022222222222186.
#   warnings.warn(
# /Users/alerico/opt/anaconda3/lib/python3.8/site-packages/scipy/stats/_continuous_distns.py:2958: RuntimeWarning: The shape parameter of the erlang distribution has been given a non-integer value 2.466666666666617.
#   warnings.warn(
# /Users/alerico/opt/anaconda3/lib/python3.8/site-packages/scipy/stats/_continuous_distns.py:2958: RuntimeWarning: The shape parameter of the erlang distribution has been given a non-integer value 2.327777777777723.
#   warnings.warn(
# /Users/alerico/opt/anaconda3/lib/python3.8/site-packages/scipy/stats/_continuous_distns.py:2958: RuntimeWarning: The shape parameter of the erlang distribution has been given a non-integer value 2.779629629629559.
#   warnings.warn(
# /Users/alerico/opt/anaconda3/lib/python3.8/site-packages/scipy/stats/_continuous_distns.py:2958: RuntimeWarning: The shape parameter of the erlang distribution has been given a non-integer value 3.3493827160492984.
#   warnings.warn(
# /Users/alerico/opt/anaconda3/lib/python3.8/site-packages/scipy/stats/_continuous_distns.py:2958: RuntimeWarning: The shape parameter of the erlang distribution has been given a non-integer value 2.1123456790123.
#   warnings.warn(
# /Users/alerico/opt/anaconda3/lib/python3.8/site-packages/scipy/stats/_continuous_distns.py:2958: RuntimeWarning: The shape parameter of the erlang distribution has been given a non-integer value 1.824897119341534.
#   warnings.warn(
# /Users/alerico/opt/anaconda3/lib/python3.8/site-packages/scipy/stats/_continuous_distns.py:2958: RuntimeWarning: The shape parameter of the erlang distribution has been given a non-integer value 2.540946502057553.
#   warnings.warn(
# /Users/alerico/opt/anaconda3/lib/python3.8/site-packages/scipy/stats/_continuous_distns.py:2958: RuntimeWarning: The shape parameter of the erlang distribution has been given a non-integer value 2.0635802469135403.
#   warnings.warn(
# /Users/alerico/opt/anaconda3/lib/python3.8/site-packages/scipy/stats/_continuous_distns.py:2958: RuntimeWarning: The shape parameter of the erlang distribution has been given a non-integer value 2.1829218106995434.
#   warnings.warn(
# /Users/alerico/opt/anaconda3/lib/python3.8/site-packages/scipy/stats/_continuous_distns.py:2958: RuntimeWarning: The shape parameter of the erlang distribution has been given a non-integer value 2.539231824416955.
#   warnings.warn(
# /Users/alerico/opt/anaconda3/lib/python3.8/site-packages/scipy/stats/_continuous_distns.py:2958: RuntimeWarning: The shape parameter of the erlang distribution has been given a non-integer value 2.219067215363464.
#   warnings.warn(
# /Users/alerico/opt/anaconda3/lib/python3.8/site-packages/scipy/stats/_continuous_distns.py:2958: RuntimeWarning: The shape parameter of the erlang distribution has been given a non-integer value 2.25132601737536.
#   warnings.warn(
# /Users/alerico/opt/anaconda3/lib/python3.8/site-packages/scipy/stats/_continuous_distns.py:2958: RuntimeWarning: The shape parameter of the erlang distribution has been given a non-integer value 2.3086648376771324.
#   warnings.warn(
# /Users/alerico/opt/anaconda3/lib/python3.8/site-packages/scipy/stats/_continuous_distns.py:2958: RuntimeWarning: The shape parameter of the erlang distribution has been given a non-integer value 2.4800106691052655.
#   warnings.warn(
# /Users/alerico/opt/anaconda3/lib/python3.8/site-packages/scipy/stats/_continuous_distns.py:2958: RuntimeWarning: The shape parameter of the erlang distribution has been given a non-integer value 2.257194025300974.
#   warnings.warn(
# /Users/alerico/opt/anaconda3/lib/python3.8/site-packages/scipy/stats/_continuous_distns.py:2958: RuntimeWarning: The shape parameter of the erlang distribution has been given a non-integer value 2.056617385561096.
#   warnings.warn(
# /Users/alerico/opt/anaconda3/lib/python3.8/site-packages/scipy/stats/_continuous_distns.py:2958: RuntimeWarning: The shape parameter of the erlang distribution has been given a non-integer value 2.1591297058374765.
#   warnings.warn(
# /Users/alerico/opt/anaconda3/lib/python3.8/site-packages/scipy/stats/_continuous_distns.py:2958: RuntimeWarning: The shape parameter of the erlang distribution has been given a non-integer value 2.1149291266574775.
#   warnings.warn(
# /Users/alerico/opt/anaconda3/lib/python3.8/site-packages/scipy/stats/_continuous_distns.py:2958: RuntimeWarning: The shape parameter of the erlang distribution has been given a non-integer value 2

#   warnings.warn(
# /Users/alerico/opt/anaconda3/lib/python3.8/site-packages/scipy/stats/_continuous_distns.py:2958: RuntimeWarning: The shape parameter of the erlang distribution has been given a non-integer value 1.6004207724164994.
#   warnings.warn(
# /Users/alerico/opt/anaconda3/lib/python3.8/site-packages/scipy/stats/_continuous_distns.py:2958: RuntimeWarning: The shape parameter of the erlang distribution has been given a non-integer value 1.6008904783567925.
#   warnings.warn(
# /Users/alerico/opt/anaconda3/lib/python3.8/site-packages/scipy/stats/_continuous_distns.py:2958: RuntimeWarning: The shape parameter of the erlang distribution has been given a non-integer value 1.6002830115607303.
#   warnings.warn(
# /Users/alerico/opt/anaconda3/lib/python3.8/site-packages/scipy/stats/_continuous_distns.py:2958: RuntimeWarning: The shape parameter of the erlang distribution has been given a non-integer value 1.5999682945838818.
#   warnings.warn(
# /Users/alerico/opt/anaconda3/lib/python3.8/site-packages/scipy/stats/_continuous_distns.py:2958: RuntimeWarning: The shape parameter of the erlang distribution has been given a non-integer value 1.5999606987442347.
#   warnings.warn(
# /Users/alerico/opt/anaconda3/lib/python3.8/site-packages/scipy/stats/_continuous_distns.py:2958: RuntimeWarning: The shape parameter of the erlang distribution has been given a non-integer value 1.6003057539984331.
#   warnings.warn(
# /Users/alerico/opt/anaconda3/lib/python3.8/site-packages/scipy/stats/_continuous_distns.py:2958: RuntimeWarning: The shape parameter of the erlang distribution has been given a non-integer value 1.6006381495198863.
#   warnings.warn(
# /Users/alerico/opt/anaconda3/lib/python3.8/site-packages/scipy/stats/_continuous_distns.py:2958: RuntimeWarning: The shape parameter of the erlang distribution has been given a non-integer value 1.600135758317883.
#   warnings.warn(
# /Users/alerico/opt/anaconda3/lib/python3.8/site-packages/scipy/stats/_continuous_distns.py:2958: RuntimeWarning: The shape parameter of the erlang distribution has been given a non-integer value 1.600225263714473.
#   warnings.warn(
# /Users/alerico/opt/anaconda3/lib/python3.8/site-packages/scipy/stats/_continuous_distns.py:2958: RuntimeWarning: The shape parameter of the erlang distribution has been given a non-integer value 1.6001963897913445.
#   warnings.warn(
# /Users/alerico/opt/anaconda3/lib/python3.8/site-packages/scipy/stats/_continuous_distns.py:2958: RuntimeWarning: The shape parameter of the erlang distribution has been given a non-integer value 1.600123616757371.
#   warnings.warn(
# /Users/alerico/opt/anaconda3/lib/python3.8/site-packages/scipy/stats/_continuous_distns.py:2958: RuntimeWarning: The shape parameter of the erlang distribution has been given a non-integer value 1.6002715796367095.
#   warnings.warn(
# /Users/alerico/opt/anaconda3/lib/python3.8/site-packages/scipy/stats/_continuous_distns.py:2958: RuntimeWarning: The shape parameter of the erlang distribution has been given a non-integer value 1.6001159804476104.
#   warnings.warn(
# /Users/alerico/opt/anaconda3/lib/python3.8/site-packages/scipy/stats/_continuous_distns.py:2958: RuntimeWarning: The shape parameter of the erlang distribution has been given a non-integer value 1.6002583106107275.
#   warnings.warn(
# /Users/alerico/opt/anaconda3/lib/python3.8/site-packages/scipy/stats/_continuous_distns.py:2958: RuntimeWarning: The shape parameter of the erlang distribution has been given a non-integer value 1.600367677656724.
#   warnings.warn(
# /Users/alerico/opt/anaconda3/lib/python3.8/site-packages/scipy/stats/_continuous_distns.py:2958: RuntimeWarning: The shape parameter of the erlang distribution has been given a non-integer value 1.6003096978220137.
#   warnings.warn(
# /Users/alerico/opt/anaconda3/lib/python3.8/site-packages/scipy/stats/_continuous_distns.py:2958: RuntimeWarning: The shape parameter of the erlang distribution has been given a non-integer value 1.6002793835047369.
#   warnings.warn(
# /Users/alerico/opt/anaconda3/lib/python3.8/site-packages/scipy/stats/_continuous_distns.py:2958: RuntimeWarning: The shape parameter of the erlang distribution has been given a non-integer value 1.6002635788342299.
#   warnings.warn(
# /Users/alerico/opt/anaconda3/lib/python3.8/site-packages/scipy/stats/_continuous_distns.py:2958: RuntimeWarning: The shape parameter of the erlang distribution has been given a non-integer value 1.600260780610435.
#   warnings.warn(
# /Users/alerico/opt/anaconda3/lib/python3.8/site-packages/scipy/stats/_continuous_distns.py:2958: RuntimeWarning: The shape parameter of the erlang distribution has been given a non-integer value 1.6002553810972975.
#   warnings.warn(
# /Users/alerico/opt/anaconda3/lib/python3.8/site-packages/scipy/stats/_continuous_distns.py:2958: RuntimeWarning: The shape parameter of the erlang distribution has been given a non-integer value 1.6003307744633126.
#   warnings.warn(
# /Users/alerico/opt/anaconda3/lib/python3.8/site-packages/scipy/stats/_continuous_distns.py:2958: RuntimeWarning: The shape parameter of the erlang distribution has been given a non-integer value 1.6002603914499711.
#   warnings.warn(
# /Users/alerico/opt/anaconda3/lib/python3.8/site-packages/scipy/stats/_continuous_distns.py:2958: RuntimeWarning: The shape parameter of the erlang distribution has been given a non-integer value 1.600304385514916.
#   warnings.warn(
# /Users/alerico/opt/anaconda3/lib/python3.8/site-packages/scipy/stats/_continuous_distns.py:2958: RuntimeWarning: The shape parameter of the erlang distribution has been given a non-integer value 1.600324788855259.
#   warnings.warn(
# /Users/alerico/opt/anaconda3/lib/python3.8/site-packages/scipy/stats/_continuous_distns.py:2958: RuntimeWarning: The shape parameter of the erlang distribution has been given a non-integer value 1.6002195972535689.
#   warnings.warn(
# /Users/alerico/opt/anaconda3/lib/python3.8/site-packages/scipy/stats/_continuous_distns.py:2958: RuntimeWarning: The shape parameter of the erlang distribution has been given a non-integer value 1.6002627841359751.
#   warnings.warn(
# /Users/alerico/opt/anaconda3/lib/python3.8/site-packages/scipy/stats/_continuous_distns.py:2958: RuntimeWarning: The shape parameter of the erlang distribution has been given a non-integer value 1.6002609896214721.
#   warnings.warn(
# ...
# /Users/alerico/opt/anaconda3/lib/python3.8/site-packages/scipy/stats/_continuous_distns.py:2958: RuntimeWarning: The shape parameter of the erlang distribution has been given a non-integer value 1.6033041307126177.
#   warnings.warn(
# /Users/alerico/opt/anaconda3/lib/python3.8/site-packages/scipy/stats/_continuous_distns.py:2958: RuntimeWarning: The shape parameter of the erlang distribution has been given a non-integer value 1.6015801161533991.
#   warnings.warn(
# /Users/alerico/opt/anaconda3/lib/python3.8/site-packages/scipy/stats/_continuous_distns.py:2958: RuntimeWarning: The shape parameter of the erlang distribution has been given a non-integer value 1.6051983072831195.
#   warnings.warn(
# /Users/alerico/opt/anaconda3/lib/python3.8/site-packages/scipy/stats/_continuous_distns.py:2958: RuntimeWarning: The shape parameter of the erlang distribution has been given a non-integer value 1.5993048648241581.
#   warnings.warn(
# /Users/alerico/opt/anaconda3/lib/python3.8/site-packages/scipy/stats/_continuous_distns.py:2958: RuntimeWarning: The shape parameter of the erlang distribution has been given a non-integer value 1.602134516324578.
#   warnings.warn(
# /Users/alerico/opt/anaconda3/lib/python3.8/site-packages/scipy/stats/_continuous_distns.py:2958: RuntimeWarning: The shape parameter of the erlang distribution has been given a non-integer value 1.5997495283308778.
#   warnings.warn(
# /Users/alerico/opt/anaconda3/lib/python3.8/site-packages/scipy/stats/_continuous_distns.py:2958: RuntimeWarning: The shape parameter of the erlang distribution has been given a non-integer value 1.6016349844856288.
#   warnings.warn(
# /Users/alerico/opt/anaconda3/lib/python3.8/site-packages/scipy/stats/_continuous_distns.py:2958: RuntimeWarning: The shape parameter of the erlang distribution has been given a non-integer value 1.6004694609361776.
#   warnings.warn(
# /Users/alerico/opt/anaconda3/lib/python3.8/site-packages/scipy/stats/_continuous_distns.py:2958: RuntimeWarning: The shape parameter of the erlang distribution has been given a non-integer value 1.5999141333275668.
#   warnings.warn(
# /Users/alerico/opt/anaconda3/lib/python3.8/site-packages/scipy/stats/_continuous_distns.py:2958: RuntimeWarning: The shape parameter of the erlang distribution has been given a non-integer value 1.5988050238393983.
#   warnings.warn(
# /Users/alerico/opt/anaconda3/lib/python3.8/site-packages/scipy/stats/_continuous_distns.py:2958: RuntimeWarning: The shape parameter of the erlang distribution has been given a non-integer value 1.601302143203283.
#   warnings.warn(
# /Users/alerico/opt/anaconda3/lib/python3.8/site-packages/scipy/stats/_continuous_distns.py:2958: RuntimeWarning: The shape parameter of the erlang distribution has been given a non-integer value 1.6029661942592344.
#   warnings.warn(
# /Users/alerico/opt/anaconda3/lib/python3.8/site-packages/scipy/stats/_continuous_distns.py:2958: RuntimeWarning: The shape parameter of the erlang distribution has been given a non-integer value 1.600220197182927.
#   warnings.warn(
# /Users/alerico/opt/anaconda3/lib/python3.8/site-packages/scipy/stats/_continuous_distns.py:2958: RuntimeWarning: The shape parameter of the erlang distribution has been given a non-integer value 1.5996928830626294.
#   warnings.warn(
# /Users/alerico/opt/anaconda3/lib/python3.8/site-packages/scipy/stats/_continuous_distns.py:2958: RuntimeWarning: The shape parameter of the erlang distribution has been given a non-integer value 1.5989528842512062.
#   warnings.warn(
# /Users/alerico/opt/anaconda3/lib/python3.8/site-packages/scipy/stats/_continuous_distns.py:2958: RuntimeWarning: The shape parameter of the erlang distribution has been given a non-integer value 1.600714828465264.
#   warnings.warn(
# /Users/alerico/opt/anaconda3/lib/python3.8/site-packages/scipy/stats/_continuous_distns.py:2958: RuntimeWarning: The shape parameter of the erlang distribution has been given a non-integer value 1.6012434413269498.
#   warnings.warn(
# /Users/alerico/opt/anaconda3/lib/python3.8/site-packages/scipy/stats/_continuous_distns.py:2958: RuntimeWarning: The shape parameter of the erlang distribution has been given a non-integer value 1.6000805226287094.
#   warnings.warn(
# /Users/alerico/opt/anaconda3/lib/python3.8/site-packages/scipy/stats/_continuous_distns.py:2958: RuntimeWarning: The shape parameter of the erlang distribution has been given a non-integer value 1.600623010837174.
#   warnings.warn(
# /Users/alerico/opt/anaconda3/lib/python3.8/site-packages/scipy/stats/_continuous_distns.py:2958: RuntimeWarning: The shape parameter of the erlang distribution has been given a non-integer value 1.600320900596489.
#   warnings.warn(
# /Users/alerico/opt/anaconda3/lib/python3.8/site-packages/scipy/stats/_continuous_distns.py:2958: RuntimeWarning: The shape parameter of the erlang distribution has been given a non-integer value 1.6002747068574643.
#   warnings.warn(
# /Users/alerico/opt/anaconda3/lib/python3.8/site-packages/scipy/stats/_continuous_distns.py:2958: RuntimeWarning: The shape parameter of the erlang distribution has been given a non-integer value 1.6004207724164994.
#   warnings.warn(
# /Users/alerico/opt/anaconda3/lib/python3.8/site-packages/scipy/stats/_continuous_distns.py:2958: RuntimeWarning: The shape parameter of the erlang distribution has been given a non-integer value 1.6008904783567925.
#   warnings.warn(
# /Users/alerico/opt/anaconda3/lib/python3.8/site-packages/scipy/stats/_continuous_distns.py:2958: RuntimeWarning: The shape parameter of the erlang distribution has been given a non-integer value 1.6002830115607303.
#   warnings.warn(
# /Users/alerico/opt/anaconda3/lib/python3.8/site-packages/scipy/stats/_continuous_distns.py:2958: RuntimeWarning: The shape parameter of the erlang distribution has been given a non-integer value 1.5999682945838818.
#   warnings.warn(
# /Users/alerico/opt/anaconda3/lib/python3.8/site-packages/scipy/stats/_continuous_distns.py:2958: RuntimeWarning: The shape parameter of the erlang distribution has been given a non-integer value 1.5999606987442347.
#   warnings.warn(
# /Users/alerico/opt/anaconda3/lib/python3.8/site-packages/scipy/stats/_continuous_distns.py:2958: RuntimeWarning: The shape parameter of the erlang distribution has been given a non-integer value 1.6003057539984331.
#   warnings.warn(
# /Users/alerico/opt/anaconda3/lib/python3.8/site-packages/scipy/stats/_continuous_distns.py:2958: RuntimeWarning: The shape parameter of the erlang distribution has been given a non-integer value 1.6006381495198863.
#   warnings.warn(
# /Users/alerico/opt/anaconda3/lib/python3.8/site-packages/scipy/stats/_continuous_distns.py:2958: RuntimeWarning: The shape parameter of the erlang distribution has been given a non-integer value 1.600135758317883.
#   warnings.warn(
# /Users/alerico/opt/anaconda3/lib/python3.8/site-packages/scipy/stats/_continuous_distns.py:2958: RuntimeWarning: The shape parameter of the erlang distribution has been given a non-integer value 1.600225263714473.
#   warnings.warn(
# /Users/alerico/opt/anaconda3/lib/python3.8/site-packages/scipy/stats/_continuous_distns.py:2958: RuntimeWarning: The shape parameter of the erlang distribution has been given a non-integer value 1.6001963897913445.
#   warnings.warn(
# /Users/alerico/opt/anaconda3/lib/python3.8/site-packages/scipy/stats/_continuous_distns.py:2958: RuntimeWarning: The shape parameter of the erlang distribution has been given a non-integer value 1.600123616757371.
#   warnings.warn(
# /Users/alerico/opt/anaconda3/lib/python3.8/site-packages/scipy/stats/_continuous_distns.py:2958: RuntimeWarning: The shape parameter of the erlang distribution has been given a non-integer value 1.6002715796367095.
#   warnings.warn(
# /Users/alerico/opt/anaconda3/lib/python3.8/site-packages/scipy/stats/_continuous_distns.py:2958: RuntimeWarning: The shape parameter of the erlang distribution has been given a non-integer value 1.6001159804476104.
#   warnings.warn(
# /Users/alerico/opt/anaconda3/lib/python3.8/site-packages/scipy/stats/_continuous_distns.py:2958: RuntimeWarning: The shape parameter of the erlang distribution has been given a non-integer value 1.6002583106107275.
#   warnings.warn(
# /Users/alerico/opt/anaconda3/lib/python3.8/site-packages/scipy/stats/_continuous_distns.py:2958: RuntimeWarning: The shape parameter of the erlang distribution has been given a non-integer value 1.600367677656724.
#   warnings.warn(
# /Users/alerico/opt/anaconda3/lib/python3.8/site-packages/scipy/stats/_continuous_distns.py:2958: RuntimeWarning: The shape parameter of the erlang distribution has been given a non-integer value 1.6003096978220137.
#   warnings.warn(
# /Users/alerico/opt/anaconda3/lib/python3.8/site-packages/scipy/stats/_continuous_distns.py:2958: RuntimeWarning: The shape parameter of the erlang distribution has been given a non-integer value 1.6002793835047369.
#   warnings.warn(
# /Users/alerico/opt/anaconda3/lib/python3.8/site-packages/scipy/stats/_continuous_distns.py:2958: RuntimeWarning: The shape parameter of the erlang distribution has been given a non-integer value 1.6002635788342299.
#   warnings.warn(
# /Users/alerico/opt/anaconda3/lib/python3.8/site-packages/scipy/stats/_continuous_distns.py:2958: RuntimeWarning: The shape parameter of the erlang distribution has been given a non-integer value 1.600260780610435.
#   warnings.warn(
# /Users/alerico/opt/anaconda3/lib/python3.8/site-packages/scipy/stats/_continuous_distns.py:2958: RuntimeWarning: The shape parameter of the erlang distribution has been given a non-integer value 1.6002553810972975.
#   warnings.warn(
# /Users/alerico/opt/anaconda3/lib/python3.8/site-packages/scipy/stats/_continuous_distns.py:2958: RuntimeWarning: The shape parameter of the erlang distribution has been given a non-integer value 1.6003307744633126.
#   warnings.warn(
# /Users/alerico/opt/anaconda3/lib/python3.8/site-packages/scipy/stats/_continuous_distns.py:2958: RuntimeWarning: The shape parameter of the erlang distribution has been given a non-integer value 1.6002603914499711.
#   warnings.warn(
# /Users/alerico/opt/anaconda3/lib/python3.8/site-packages/scipy/stats/_continuous_distns.py:2958: RuntimeWarning: The shape parameter of the erlang distribution has been given a non-integer value 1.600304385514916.
#   warnings.warn(
# /Users/alerico/opt/anaconda3/lib/python3.8/site-packages/scipy/stats/_continuous_distns.py:2958: RuntimeWarning: The shape parameter of the erlang distribution has been given a non-integer value 1.600324788855259.
#   warnings.warn(
# /Users/alerico/opt/anaconda3/lib/python3.8/site-packages/scipy/stats/_continuous_distns.py:2958: RuntimeWarning: The shape parameter of the erlang distribution has been given a non-integer value 1.6002195972535689.
#   warnings.warn(
# /Users/alerico/opt/anaconda3/lib/python3.8/site-packages/scipy/stats/_continuous_distns.py:2958: RuntimeWarning: The shape parameter of the erlang distribution has been given a non-integer value 1.6002627841359751.
#   warnings.warn(
# /Users/alerico/opt/anaconda3/lib/python3.8/site-packages/scipy/stats/_continuous_distns.py:2958: RuntimeWarning: The shape parameter of the erlang distribution has been given a non-integer value 1.6002609896214721.
#   warnings.warn(
# /Users/alerico/opt/anaconda3/lib/python3.8/site-packages/scipy/stats/_continuous_distns.py:2958: RuntimeWarning: The shape parameter of the erlang distribution has been given a non-integer value 1.6003311732443128.
#   warnings.warn(
# /Users/alerico/opt/anaconda3/lib/python3.8/site-packages/scipy/stats/_continuous_distns.py:2958: RuntimeWarning: The shape parameter of the erlang distribution has been given a non-integer value 1.6002474912512548.
#   warnings.warn(
# /Users/alerico/opt/anaconda3/lib/python3.8/site-packages/scipy/stats/_continuous_distns.py:2958: RuntimeWarning: The shape parameter of the erlang distribution has been given a non-integer value 1.6002811303146602.
#   warnings.warn(
# /Users/alerico/opt/anaconda3/lib/python3.8/site-packages/scipy/stats/_continuous_distns.py:2958: RuntimeWarning: The shape parameter of the erlang distribution has been given a non-integer value 1.6003168457161108.
#   warnings.warn(
# /Users/alerico/opt/anaconda3/lib/python3.8/site-packages/scipy/stats/_continuous_distns.py:2958: RuntimeWarning: The shape parameter of the erlang distribution has been given a non-integer value 1.6003405847423189.
#   warnings.warn(
# /Users/alerico/opt/anaconda3/lib/python3.8/site-packages/scipy/stats/_continuous_distns.py:2958: RuntimeWarning: The shape parameter of the erlang distribution has been given a non-integer value 1.6003005546651528.
#   warnings.warn(
# /Users/alerico/opt/anaconda3/lib/python3.8/site-packages/scipy/stats/_continuous_distns.py:2958: RuntimeWarning: The shape parameter of the erlang distribution has been given a non-integer value 1.6002924091396737.
#   warnings.warn(
# /Users/alerico/opt/anaconda3/lib/python3.8/site-packages/scipy/stats/_continuous_distns.py:2958: RuntimeWarning: The shape parameter of the erlang distribution has been given a non-integer value 1.6002501289208333.
#   warnings.warn(
# /Users/alerico/opt/anaconda3/lib/python3.8/site-packages/scipy/stats/_continuous_distns.py:2958: RuntimeWarning: The shape parameter of the erlang distribution has been given a non-integer value 1.6003179707869475.
#   warnings.warn(
# /Users/alerico/opt/anaconda3/lib/python3.8/site-packages/scipy/stats/_continuous_distns.py:2958: RuntimeWarning: The shape parameter of the erlang distribution has been given a non-integer value 1.6003341436633503.
#   warnings.warn(
# /Users/alerico/opt/anaconda3/lib/python3.8/site-packages/scipy/stats/_continuous_distns.py:2958: RuntimeWarning: The shape parameter of the erlang distribution has been given a non-integer value 1.6002943836518329.
#   warnings.warn(
# /Users/alerico/opt/anaconda3/lib/python3.8/site-packages/scipy/stats/_continuous_distns.py:2958: RuntimeWarning: The shape parameter of the erlang distribution has been given a non-integer value 1.6003042205543725.
#   warnings.warn(
# /Users/alerico/opt/anaconda3/lib/python3.8/site-packages/scipy/stats/_continuous_distns.py:2958: RuntimeWarning: The shape parameter of the erlang distribution has been given a non-integer value 1.6003042617945085.
#   warnings.warn(
# /Users/alerico/opt/anaconda3/lib/python3.8/site-packages/scipy/stats/_continuous_distns.py:2958: RuntimeWarning: The shape parameter of the erlang distribution has been given a non-integer value 1.6003208078459066.
#   warnings.warn(
# /Users/alerico/opt/anaconda3/lib/python3.8/site-packages/scipy/stats/_continuous_distns.py:2958: RuntimeWarning: The shape parameter of the erlang distribution has been given a non-integer value 1.6003340199429434.
#   warnings.warn(
# /Users/alerico/opt/anaconda3/lib/python3.8/site-packages/scipy/stats/_continuous_distns.py:2958: RuntimeWarning: The shape parameter of the erlang distribution has been given a non-integer value 1.6003281389530888.
#   warnings.warn(
# /Users/alerico/opt/anaconda3/lib/python3.8/site-packages/scipy/stats/_continuous_distns.py:2958: RuntimeWarning: The shape parameter of the erlang distribution has been given a non-integer value 1.6003074507371369.
#   warnings.warn(
# /Users/alerico/opt/anaconda3/lib/python3.8/site-packages/scipy/stats/_continuous_distns.py:2958: RuntimeWarning: The shape parameter of the erlang distribution has been given a non-integer value 1.600303709464754.
#   warnings.warn(
# /Users/alerico/opt/anaconda3/lib/python3.8/site-packages/scipy/stats/_continuous_distns.py:2958: RuntimeWarning: The shape parameter of the erlang distribution has been given a non-integer value 1.6003144054563991.
#   warnings.warn(
# /Users/alerico/opt/anaconda3/lib/python3.8/site-packages/scipy/stats/_continuous_distns.py:2958: RuntimeWarning: The shape parameter of the erlang distribution has been given a non-integer value array(1.60030745).
#   warnings.warn(
# /Users/alerico/opt/anaconda3/lib/python3.8/site-packages/scipy/stats/_continuous_distns.py:2958: RuntimeWarning: The shape parameter of the erlang distribution has been given a non-integer value array(1.60030745).
#   warnings.warn(

# %% [markdown]
# > La distribución de probabilidad que mejor se ajusta a nuestros datos es **EXPONNORM**, en la cual podemos observar claramente que la cola derecha tiene un mayor peso que la izquierda.

# %% [markdown]
# ## Parámetros

# %%
params = st.exponnorm.fit(prom_TT)

# Separate parts of parameters
arg = params[:-2]
loc1 = params[-2]
scale1 = params[-1]

c = arg[0]

print('c=',c,'loc=',loc1,'scale=',scale1)
# Out:
# c= 7.023487470396008 loc= 11.602853946231365 scale= 2.9831996055872665

# %% [markdown]
# ## Intervalo de confianza

# %%
np.random.seed(55555)

N = 100
confianza = 0.95
X = st.exponnorm.rvs(c,loc1,scale1,N)
st.sem
i1 = st.t.interval(confianza,len(X)-1, loc=np.mean(X), scale=st.sem(X))
print('Con una confianza de %2.2f la media estará en el intervalo t,\n %s' %(confianza,i1))
print('Media calculada' ,np.mean(X))
# Out:
# Con una confianza de 0.95 la media estará en el intervalo t,
#  (28.228740151765763, 36.93245464517011)
# Media calculada 32.58059739846794

# %% [markdown]
# ## Prueba chi cuadrado - Histograma

# %%
np.random.seed(555)
mu_real = prom_TT.mean()
sigma_real = prom_TT.std()
N = 100 # Cantidad de muestras
n1 = st.exponnorm.rvs(c,loc1,scale1, size=1000)
J = 90  # Cantidad de particiones del histograma
plt.figure(figsize=(8,6))
[freq, x, _] = plt.hist(n1, J, density=True,color='orange')
plt.title('Histograma de datos con distribución DWEIBULL',size=13)
plt.show()

# Se obvia el último valor de x para obtener exactamente J muestras de x
x = x[:-1] 

# Media y desviación estándar muestral
mu = np.mean(x)
sigma = np.std(x)
print('media mu =%f, desviación estándar muestral =%f'%(mu,sigma))
# Out:
# media mu =29.579547, desviación estándar muestral =15.576611

# %% [markdown]
# ### Prueba de hipótesis
#
# > $H_0$: la distribución es exponnorm.
#
# > $H_a$: la distribución no es exponnorm.

# %%
pi = st.exponnorm.pdf(x, c,loc1,scale1)
# Cálculo de la esperanza usando la expresión teórica
Ei = x*pi
# Cálculo teórico de la chi cuadrada
x2 = np.sum(list(map(lambda Ei, obs_i:(obs_i - Ei)**2 / Ei, Ei, freq)))
print('Valor de chi cuadrado teorico  = ', x2)

# Cálculo usando la librería estadística de la chi cuadrada
X2 = st.chisquare(freq, Ei)
print('Valor de chi cuadrado librería = ', X2)

# Cálculo de Grados de libertad del estadístico
p = 2 # Parámetros estimados con los datos
m = J-p-1 # grados de libertad

Chi_est = st.chi2.ppf(q=0.95, df=m)
print('Estadístico de chi_cuadrado = ', Chi_est)
print('Media muestral = ', mu, '\nDesviación estándar muestral = ', sigma)
# Out:
# Valor de chi cuadrado teorico  =  26.791401300048417
# Valor de chi cuadrado librería =  Power_divergenceResult(statistic=26.791401300048417, pvalue=0.9999999999829324)
# Estadístico de chi_cuadrado =  109.77330935028795
# Media muestral =  29.579547324190106
# Desviación estándar muestral =  15.576611215890672

# %% [markdown]
# > No se rechaza la $H_0$ por lo tanto, los datos distribuyen exponnorm.

# %% [markdown]
# ## Muestreo estratificado

# %%
N = 500
# (Método transformada inversa visto en clases pasadas)
# Método montecarlo estándar 
montecarlo_standar = st.exponnorm.ppf(np.random.rand(N),c)
plt.figure(figsize=(10,8))
plt.hist(montecarlo_standar,120,density=True,color='orange')
plt.title('Montecarlo estándar')
plt.show()

# Método muestreo estratificado (B estratos)
B = N
U2 = np.random.rand(B)
i = np.arange(0,B)
v = (U2+i)/B
m_estratificado = st.exponnorm.ppf(v,c)

plt.figure(figsize=(10,8))
plt.hist(m_estratificado,120,density=True,color='gold')
plt.title('Muestreo estratificado')
plt.show()

# %% [markdown]
# > Gracias a los estratos generados, los datos y la distribución se observan mucho más claros y mejor distribuida.

# %% [markdown]
# ## Conclusión

# %% [markdown]
# # Nodo 2. Tiempos frente al cliente

# %%
CT = data.groupby(['Categoría']).mean()
prom_CT2 = CT['Tiempo frente al cliente']
prom_CT2.head()
# Out:
# Categoría
# APOYO VIA TELEFONICA     0.146677
# AUDITORIA DE SERVICIO    1.349174
# CALL CENTER              0.046383
# CAMBIO DE UBICACION      0.962393
# CM                       0.108180
# Name: Tiempo frente al cliente, dtype: float64

# %%
x_grid = np.linspace(-2, 12, 1000)
x = prom_CT2

# %%
grid = GridSearchCV(KernelDensity(),
                    {'bandwidth': np.linspace(0.015, .02, 30)},
                    cv=20) # 20-fold cross-validation
grid.fit(x[:, None])
print(grid.best_params_)

kde = grid.best_estimator_
pdf = np.exp(kde.score_samples(x_grid[:, None]))

fig, ax = plt.subplots(figsize=(8,6))
ax.plot(x_grid, pdf, linewidth=3, alpha=0.5, label='bw=%.2f' % kde.bandwidth)
ax.hist(x, 30, fc='gray', histtype='stepfilled', alpha=0.3, density=True)
ax.legend(loc='upper left')
ax.set_xlim(-1,3);
# Out:
# {'bandwidth': 0.02}

# %% [markdown]
# ### Método de aceptación y rechazo

# %%
def kde_sklearn(x, x_grid, bandwidth=0.2, **kwargs):
    """Kernel Density Estimation with Scikit-learn"""
    kde_skl = KernelDensity(bandwidth=bandwidth, **kwargs)
    kde_skl.fit(x[:, np.newaxis])
    # score_samples() returns the log-likelihood of the samples
    pdf = lambda x: np.exp(kde_skl.score_samples(x[:, np.newaxis]))
    return pdf

# %%
# Función objetivo 
data2 = np.asarray(prom_CT2)
f = kde_sklearn(data2, x_grid, bandwidth=0.02)
# Máximo de la función f
max_f = max(f(x))
# Función t
t = lambda x: max_f*np.ones(len(x))
x =  np.arange(-0.5,2.5,0.01)   # Rango donde se graficará las funciones
print('Máximo de f:',max_f)
# Gráficas de las funciones
plt.figure(figsize=(10,8))
plt.plot(x,f(x),label='f(x)')
plt.plot(x,t(x),label='t(x)')
plt.legend()

# Validación del método
N = 10000 # número de puntos a simular
R2 = np.random.rand(N)
R1 = np.random.uniform(-0.5,2.5,N)

Acep_rechazo(R2,R1,f,t)
# Out:
# Máximo de f: 3.5357941010751492
# /Users/alerico/opt/anaconda3/lib/python3.8/site-packages/IPython/core/pylabtools.py:132: UserWarning: Creating legend with loc="best" can be slow with large amounts of data.
#   fig.canvas.print_figure(bytes_io, **kw)

# %%
# Función objetivo 
f = kde_sklearn(data2, x_grid, bandwidth=0.02)
x =  np.arange(-0.5,2.5,0.01)  # Rango donde se graficará las funciones
# Gráfica de la función
plt.figure(figsize=(10,8))
plt.plot(x,f(x),label='f(x)')
plt.legend()

t = lambda x: max_f*np.ones(len(x))
N = 1000
R2 = np.random.rand(N)
R1 = np.random.uniform(-0.5,2.5,N)
histograma(R2, R1, f, t)

# %% [markdown]
# > El bandwith óptimo a utilizar es 0.02

# %% [markdown]
# ## Ajuste de distribución

# %%
distribucion(prom_CT2, 10)
# Out:
# /Users/alerico/opt/anaconda3/lib/python3.8/site-packages/scipy/stats/_continuous_distns.py:2958: RuntimeWarning: The shape parameter of the erlang distribution has been given a non-integer value 128.1.
#   warnings.warn(
# /Users/alerico/opt/anaconda3/lib/python3.8/site-packages/scipy/stats/_continuous_distns.py:2958: RuntimeWarning: The shape parameter of the erlang distribution has been given a non-integer value 115.9.
#   warnings.warn(
# /Users/alerico/opt/anaconda3/lib/python3.8/site-packages/scipy/stats/_continuous_distns.py:2958: RuntimeWarning: The shape parameter of the erlang distribution has been given a non-integer value 117.93333333333331.
#   warnings.warn(
# /Users/alerico/opt/anaconda3/lib/python3.8/site-packages/scipy/stats/_continuous_distns.py:2958: RuntimeWarning: The shape parameter of the erlang distribution has been given a non-integer value 120.98333333333332.
#   warnings.warn(
# /Users/alerico/opt/anaconda3/lib/python3.8/site-packages/scipy/stats/_continuous_distns.py:2958: RuntimeWarning: The shape parameter of the erlang distribution has been given a non-integer value 127.42222222222222.
#   warnings.warn(
# /Users/alerico/opt/anaconda3/lib/python3.8/site-packages/scipy/stats/_continuous_distns.py:2958: RuntimeWarning: The shape parameter of the erlang distribution has been given a non-integer value 124.93703703703704.
#   warnings.warn(
# /Users/alerico/opt/anaconda3/lib/python3.8/site-packages/scipy/stats/_continuous_distns.py:2958: RuntimeWarning: The shape parameter of the erlang distribution has been given a non-integer value 122.73425925925926.
#   warnings.warn(
# /Users/alerico/opt/anaconda3/lib/python3.8/site-packages/scipy/stats/_continuous_distns.py:2958: RuntimeWarning: The shape parameter of the erlang distribution has been given a non-integer value 116.38950617283953.
#   warnings.warn(
# /Users/alerico/opt/anaconda3/lib/python3.8/site-packages/scipy/stats/_continuous_distns.py:2958: RuntimeWarning: The shape parameter of the erlang distribution has been given a non-integer value 124.66404320987655.
#   warnings.warn(
# /Users/alerico/opt/anaconda3/lib/python3.8/site-packages/scipy/stats/_continuous_distns.py:2958: RuntimeWarning: The shape parameter of the erlang distribution has been given a non-integer value 122.36399176954731.
#   warnings.warn(
# /Users/alerico/opt/anaconda3/lib/python3.8/site-packages/scipy/stats/_continuous_distns.py:2958: RuntimeWarning: The shape parameter of the erlang distribution has been given a non-integer value 122.64169238683127.
#   warnings.warn(
# /Users/alerico/opt/anaconda3/lib/python3.8/site-packages/scipy/stats/_continuous_distns.py:2958: RuntimeWarning: The shape parameter of the erlang distribution has been given a non-integer value 119.08597393689982.
#   warnings.warn(
# /Users/alerico/opt/anaconda3/lib/python3.8/site-packages/scipy/stats/_continuous_distns.py:2958: RuntimeWarning: The shape parameter of the erlang distribution has been given a non-integer value 121.5017775491541.
#   warnings.warn(
# /Users/alerico/opt/anaconda3/lib/python3.8/site-packages/scipy/stats/_continuous_distns.py:2958: RuntimeWarning: The shape parameter of the erlang distribution has been given a non-integer value 121.11294438728851.
#   warnings.warn(
# /Users/alerico/opt/anaconda3/lib/python3.8/site-packages/scipy/stats/_continuous_distns.py:2958: RuntimeWarning: The shape parameter of the erlang distribution has been given a non-integer value 124.75045057918004.
#   warnings.warn(
# /Users/alerico/opt/anaconda3/lib/python3.8/site-packages/scipy/stats/_continuous_distns.py:2958: RuntimeWarning: The shape parameter of the erlang distribution has been given a non-integer value 123.33433141860998.
#   warnings.warn(
# /Users/alerico/opt/anaconda3/lib/python3.8/site-packages/scipy/stats/_continuous_distns.py:2958: RuntimeWarning: The shape parameter of the erlang distribution has been given a non-integer value 121.65649148376772.
#   warnings.warn(
# /Users/alerico/opt/anaconda3/lib/python3.8/site-packages/scipy/stats/_continuous_distns.py:2958: RuntimeWarning: The shape parameter of the erlang distribution has been given a non-integer value 122.39539216106539.
#   warnings.warn(
# /Users/alerico/opt/anaconda3/lib/python3.8/site-packages/scipy/stats/_continuous_distns.py:2958: RuntimeWarning: The shape parameter of the erlang distribution has been given a non-integer value 124.04020466582838.
#   warnings.warn(
# /Users/alerico/opt/anaconda3/lib/python3.8/site-packages/scipy/stats/_continuous_distns.py:2958: RuntimeWarning: The shape parameter of the erlang distribution has been given a non-integer value 122.28939979931918.
#   warnings.warn(
# /Users/alerico/opt/anaconda3/lib/python3.8/site-packages/scipy/stats/_continuous_distns.py:2958: RuntimeWarning: The shape parameter of the erlang distribution has been given a non-integer value 123.07309851378727.
#   warnings.warn(
# /Users/alerico/opt/anaconda3/lib/python3.8/site-packages/scipy/stats/_continuous_distns.py:2958: RuntimeWarning: The shape parameter of the erlang distribution has been given a non-integer value 120.93878911740671.
#   warnings.warn(
# /Users/alerico/opt/anaconda3/lib/python3.8/site-packages/scipy/stats/_continuous_distns.py:2958: RuntimeWarning: The shape parameter of the erlang distribution has been given a non-integer value 123.26485077872297.
#   warnings.warn(
# /Users/alerico/opt/anaconda3/lib/python3.8/site-packages/scipy/stats/_continuous_distns.py:2958: RuntimeWarning: The shape parameter of the erlang distribution has been given a non-integer value 123.1632407006081.
#   warnings.warn(
# /Users/alerico/opt/anaconda3/lib/python3.8/site-packages/scipy/stats/_continuous_distns.py:2958: RuntimeWarning: The shape parameter of the erlang distribution has been given a non-integer value 122.22604203087391.
#   warnings.warn(
# /Users/alerico/opt/anaconda3/lib/python3.8/site-packages/scipy/stats/_continuous_distns.py:2958: RuntimeWarning: The shape parameter of the erlang distribution has been given a non-integer value 123.0051485917607.
#   warnings.warn(
# /Users/alerico/opt/anaconda3/lib/python3.8/site-packages/scipy/stats/_continuous_distns.py:2958: RuntimeWarning: The shape parameter of the erlang distribution has been given a non-integer value 122.37249434779196.
#   warnings.warn(
# /Users/alerico/opt/anaconda3/lib/python3.8/site-packages/scipy/stats/_continuous_distns.py:2958: RuntimeWarning: The shape parameter of the erlang distribution has been given a non-integer value 122.02219226479428.
#   warnings.warn(
# /Users/alerico/opt/anaconda3/lib/python3.8/site-packages/scipy/stats/_continuous_distns.py:2958: RuntimeWarning: The shape parameter of the erlang distribution has been given a non-integer value 121.75518792576031.
#   warnings.warn(
# /Users/alerico/opt/anaconda3/lib/python3.8/site-packages/scipy/stats/_continuous_distns.py:2958: RuntimeWarning: The shape parameter of the erlang distribution has been given a non-integer value 122.81122750689616.
#   warnings.warn(
# /Users/alerico/opt/anaconda3/lib/python3.8/site-packages/scipy/stats/_continuous_distns.py:2958: RuntimeWarning: The shape parameter of the erlang distribution has been given a non-integer value 121.78399931136468.
#   warnings.warn(
# /Users/alerico/opt/anaconda3/lib/python3.8/site-packages/scipy/stats/_continuous_distns.py:2958: RuntimeWarning: The shape parameter of the erlang distribution has been given a non-integer value 121.17342467116669.
#   warnings.warn(
# /Users/alerico/opt/anaconda3/lib/python3.8/site-packages/scipy/stats/_continuous_distns.py:2958: RuntimeWarning: The shape parameter of the erlang distribution has been given a non-integer value 122.64514744403519.
#   warnings.warn(
# /Users/alerico/opt/anaconda3/lib/python3.8/site-packages/scipy/stats/_continuous_distns.py:2958: RuntimeWarning: The shape parameter of the erlang distribution has been given a non-integer value 122.16128686100879.
#   warnings.warn(
# /Users/alerico/opt/anaconda3/lib/python3.8/site-packages/scipy/stats/_continuous_distns.py:2958: RuntimeWarning: The shape parameter of the erlang distribution has been given a non-integer value 121.40062617321414.
#   warnings.warn(
# /Users/alerico/opt/anaconda3/lib/python3.8/site-packages/scipy/stats/_continuous_distns.py:2958: RuntimeWarning: The shape parameter of the erlang distribution has been given a non-integer value 120.69532550637314.
#   warnings.warn(
# /Users/alerico/opt/anaconda3/lib/python3.8/site-packages/scipy/stats/_continuous_distns.py:2958: RuntimeWarning: The shape parameter of the erlang distribution has been given a non-integer value 121.19144721593312.
#   warnings.warn(
# /Users/alerico/opt/anaconda3/lib/python3.8/site-packages/scipy/stats/_continuous_distns.py:2958: RuntimeWarning: The shape parameter of the erlang distribution has been given a non-integer value 120.60092365000372.
#   warnings.warn(
# /Users/alerico/opt/anaconda3/lib/python3.8/site-packages/scipy/stats/_continuous_distns.py:2958: RuntimeWarning: The shape parameter of the erlang distribution has been given a non-integer value 121.3849075220727.
#   warnings.warn(
# /Users/alerico/opt/anaconda3/lib/python3.8/site-packages/scipy/stats/_continuous_distns.py:2958: RuntimeWarning: The shape parameter of the erlang distribution has been given a non-integer value 121.18536162742669.
#   warnings.warn(
# /Users/alerico/opt/anaconda3/lib/python3.8/site-packages/scipy/stats/_continuous_distns.py:2958: RuntimeWarning: The shape parameter of the erlang distribution has been given a non-integer value 120.49003374647117.
#   warnings.warn(
# /Users/alerico/opt/anaconda3/lib/python3.8/site-packages/scipy/stats/_continuous_distns.py:2958: RuntimeWarning: The shape parameter of the erlang distribution has been given a non-integer value 119.65440718920235.
#   warnings.warn(
# /Users/alerico/opt/anaconda3/lib/python3.8/site-packages/scipy/stats/_continuous_distns.py:2958: RuntimeWarning: The shape parameter of the erlang distribution has been given a non-integer value 120.08654844492463.
#   warnings.warn(
# /Users/alerico/opt/anaconda3/lib/python3.8/site-packages/scipy/stats/_continuous_distns.py:2958: RuntimeWarning: The shape parameter of the erlang distribution has been given a non-integer value 119.55912822153331.
#   warnings.warn(
# /Users/alerico/opt/anaconda3/lib/python3.8/site-packages/scipy/stats/_continuous_distns.py:2958: RuntimeWarning: The shape parameter of the erlang distribution has been given a non-integer value 118.1484817150342.
#   warnings.warn(
# /Users/alerico/opt/anaconda3/lib/python3.8/site-packages/scipy/stats/_continuous_distns.py:2958: RuntimeWarning: The shape parameter of the erlang distribution has been given a non-integer value 116.53026881151493.
#   warnings.warn(
# /Users/alerico/opt/anaconda3/lib/python3.8/site-packages/scipy/stats/_continuous_distns.py:2958: RuntimeWarning: The shape parameter of the erlang distribution has been given a non-integer value 117.95502140889462.
#   warnings.warn(
# /Users/alerico/opt/anaconda3/lib/python3.8/site-packages/scipy/stats/_continuous_distns.py:2958: RuntimeWarning: The shape parameter of the erlang distribution has been given a non-integer value 116.00658316148332.
#   warnings.warn(
# /Users/alerico/opt/anaconda3/lib/python3.8/site-packages/scipy/stats/_continuous_distns.py:2958: RuntimeWarning: The shape parameter of the erlang distribution has been given a non-integer value 119.0665571240643.
#   warnings.warn(
# /Users/alerico/opt/anaconda3/lib/python3.8/site-packages/scipy/stats/_continuous_distns.py:2958: RuntimeWarning: The shape parameter of the erlang distribution has been given a non-integer value 116.04682437378023.
#   warnings.warn(
# /Users/alerico/opt/anaconda3/lib/python3.8/site-packages/scipy/stats/_continuous_distns.py:2958: RuntimeWarning: The shape parameter of the erlang distribution has been given a non-integer value 114.24303296606917.
#   warnings.warn(
# /Users/alerico/opt/anaconda3/lib/python3.8/site-packages/scipy/stats/_continuous_distns.py:2958: RuntimeWarning: The shape parameter of the erlang distribution has been given a non-integer value 113.41899166692153.
#   warnings.warn(
# /Users/alerico/opt/anaconda3/lib/python3.8/site-packages/scipy/stats/_continuous_distns.py:2958: RuntimeWarning: The shape parameter of the erlang distribution has been given a non-integer value 111.5065075541091.
#   warnings.warn(
# /Users/alerico/opt/anaconda3/lib/python3.8/site-packages/scipy/stats/_continuous_distns.py:2958: RuntimeWarning: The shape parameter of the erlang distribution has been given a non-integer value 116.34289294519824.
#   warnings.warn(
# /Users/alerico/opt/anaconda3/lib/python3.8/site-packages/scipy/stats/_continuous_distns.py:2958: RuntimeWarning: The shape parameter of the erlang distribution has been given a non-integer value 112.8063429072777.
#   warnings.warn(
# /Users/alerico/opt/anaconda3/lib/python3.8/site-packages/scipy/stats/_continuous_distns.py:2958: RuntimeWarning: The shape parameter of the erlang distribution has been given a non-integer value 110.94437995515909.
#   warnings.warn(
# /Users/alerico/opt/anaconda3/lib/python3.8/site-packages/scipy/stats/_continuous_distns.py:2958: RuntimeWarning: The shape parameter of the erlang distribution has been given a non-integer value 114.26787891069614.
#   warnings.warn(
# /Users/alerico/opt/anaconda3/lib/python3.8/site-packages/scipy/stats/_continuous_distns.py:2958: RuntimeWarning: The shape parameter of the erlang distribution has been given a non-integer value

#   warnings.warn(
# /Users/alerico/opt/anaconda3/lib/python3.8/site-packages/scipy/stats/_continuous_distns.py:2958: RuntimeWarning: The shape parameter of the erlang distribution has been given a non-integer value 14.147222920540706.
#   warnings.warn(
# /Users/alerico/opt/anaconda3/lib/python3.8/site-packages/scipy/stats/_continuous_distns.py:2958: RuntimeWarning: The shape parameter of the erlang distribution has been given a non-integer value 15.217722628095675.
#   warnings.warn(
# /Users/alerico/opt/anaconda3/lib/python3.8/site-packages/scipy/stats/_continuous_distns.py:2958: RuntimeWarning: The shape parameter of the erlang distribution has been given a non-integer value 15.252807061186346.
#   warnings.warn(
# /Users/alerico/opt/anaconda3/lib/python3.8/site-packages/scipy/stats/_continuous_distns.py:2958: RuntimeWarning: The shape parameter of the erlang distribution has been given a non-integer value 15.199047119490551.
#   warnings.warn(
# /Users/alerico/opt/anaconda3/lib/python3.8/site-packages/scipy/stats/_continuous_distns.py:2958: RuntimeWarning: The shape parameter of the erlang distribution has been given a non-integer value 15.205157372460853.
#   warnings.warn(
# /Users/alerico/opt/anaconda3/lib/python3.8/site-packages/scipy/stats/_continuous_distns.py:2958: RuntimeWarning: The shape parameter of the erlang distribution has been given a non-integer value 14.47321974324753.
#   warnings.warn(
# /Users/alerico/opt/anaconda3/lib/python3.8/site-packages/scipy/stats/_continuous_distns.py:2958: RuntimeWarning: The shape parameter of the erlang distribution has been given a non-integer value 15.192782930762775.
#   warnings.warn(
# /Users/alerico/opt/anaconda3/lib/python3.8/site-packages/scipy/stats/_continuous_distns.py:2958: RuntimeWarning: The shape parameter of the erlang distribution has been given a non-integer value 14.692310567571564.
#   warnings.warn(
# /Users/alerico/opt/anaconda3/lib/python3.8/site-packages/scipy/stats/_continuous_distns.py:2958: RuntimeWarning: The shape parameter of the erlang distribution has been given a non-integer value 14.429604537309508.
#   warnings.warn(
# /Users/alerico/opt/anaconda3/lib/python3.8/site-packages/scipy/stats/_continuous_distns.py:2958: RuntimeWarning: The shape parameter of the erlang distribution has been given a non-integer value 14.208464669268949.
#   warnings.warn(
# /Users/alerico/opt/anaconda3/lib/python3.8/site-packages/scipy/stats/_continuous_distns.py:2958: RuntimeWarning: The shape parameter of the erlang distribution has been given a non-integer value 14.946703365389318.
#   warnings.warn(
# /Users/alerico/opt/anaconda3/lib/python3.8/site-packages/scipy/stats/_continuous_distns.py:2958: RuntimeWarning: The shape parameter of the erlang distribution has been given a non-integer value 15.243683604878722.
#   warnings.warn(
# /Users/alerico/opt/anaconda3/lib/python3.8/site-packages/scipy/stats/_continuous_distns.py:2958: RuntimeWarning: The shape parameter of the erlang distribution has been given a non-integer value 14.665835708655328.
#   warnings.warn(
# /Users/alerico/opt/anaconda3/lib/python3.8/site-packages/scipy/stats/_continuous_distns.py:2958: RuntimeWarning: The shape parameter of the erlang distribution has been given a non-integer value 14.162381954745552.
#   warnings.warn(
# /Users/alerico/opt/anaconda3/lib/python3.8/site-packages/scipy/stats/_continuous_distns.py:2958: RuntimeWarning: The shape parameter of the erlang distribution has been given a non-integer value 13.891844768417606.
#   warnings.warn(
# /Users/alerico/opt/anaconda3/lib/python3.8/site-packages/scipy/stats/_continuous_distns.py:2958: RuntimeWarning: The shape parameter of the erlang distribution has been given a non-integer value 13.656718464993117.
#   warnings.warn(
# /Users/alerico/opt/anaconda3/lib/python3.8/site-packages/scipy/stats/_continuous_distns.py:2958: RuntimeWarning: The shape parameter of the erlang distribution has been given a non-integer value 13.152159843162014.
#   warnings.warn(
# /Users/alerico/opt/anaconda3/lib/python3.8/site-packages/scipy/stats/_continuous_distns.py:2958: RuntimeWarning: The shape parameter of the erlang distribution has been given a non-integer value 14.273958536281178.
#   warnings.warn(
# /Users/alerico/opt/anaconda3/lib/python3.8/site-packages/scipy/stats/_continuous_distns.py:2958: RuntimeWarning: The shape parameter of the erlang distribution has been given a non-integer value 14.465015420212964.
#   warnings.warn(
# /Users/alerico/opt/anaconda3/lib/python3.8/site-packages/scipy/stats/_continuous_distns.py:2958: RuntimeWarning: The shape parameter of the erlang distribution has been given a non-integer value 14.07780573764365.
#   warnings.warn(
# /Users/alerico/opt/anaconda3/lib/python3.8/site-packages/scipy/stats/_continuous_distns.py:2958: RuntimeWarning: The shape parameter of the erlang distribution has been given a non-integer value 14.035517629092702.
#   warnings.warn(
# /Users/alerico/opt/anaconda3/lib/python3.8/site-packages/scipy/stats/_continuous_distns.py:2958: RuntimeWarning: The shape parameter of the erlang distribution has been given a non-integer value 13.576050621969124.
#   warnings.warn(
# /Users/alerico/opt/anaconda3/lib/python3.8/site-packages/scipy/stats/_continuous_distns.py:2958: RuntimeWarning: The shape parameter of the erlang distribution has been given a non-integer value 13.149273664298931.
#   warnings.warn(
# /Users/alerico/opt/anaconda3/lib/python3.8/site-packages/scipy/stats/_continuous_distns.py:2958: RuntimeWarning: The shape parameter of the erlang distribution has been given a non-integer value 14.01064016048939.
#   warnings.warn(
# /Users/alerico/opt/anaconda3/lib/python3.8/site-packages/scipy/stats/_continuous_distns.py:2958: RuntimeWarning: The shape parameter of the erlang distribution has been given a non-integer value 13.217854505340135.
#   warnings.warn(
# /Users/alerico/opt/anaconda3/lib/python3.8/site-packages/scipy/stats/_continuous_distns.py:2958: RuntimeWarning: The shape parameter of the erlang distribution has been given a non-integer value 12.689802489869614.
#   warnings.warn(
# /Users/alerico/opt/anaconda3/lib/python3.8/site-packages/scipy/stats/_continuous_distns.py:2958: RuntimeWarning: The shape parameter of the erlang distribution has been given a non-integer value 12.840706482441984.
#   warnings.warn(
# /Users/alerico/opt/anaconda3/lib/python3.8/site-packages/scipy/stats/_continuous_distns.py:2958: RuntimeWarning: The shape parameter of the erlang distribution has been given a non-integer value 12.222156854841153.
#   warnings.warn(
# /Users/alerico/opt/anaconda3/lib/python3.8/site-packages/scipy/stats/_continuous_distns.py:2958: RuntimeWarning: The shape parameter of the erlang distribution has been given a non-integer value 12.127916274231309.
#   warnings.warn(
# /Users/alerico/opt/anaconda3/lib/python3.8/site-packages/scipy/stats/_continuous_distns.py:2958: RuntimeWarning: The shape parameter of the erlang distribution has been given a non-integer value 13.539959188924868.
#   warnings.warn(
# /Users/alerico/opt/anaconda3/lib/python3.8/site-packages/scipy/stats/_continuous_distns.py:2958: RuntimeWarning: The shape parameter of the erlang distribution has been given a non-integer value 13.249739786839058.
#   warnings.warn(
# /Users/alerico/opt/anaconda3/lib/python3.8/site-packages/scipy/stats/_continuous_distns.py:2958: RuntimeWarning: The shape parameter of the erlang distribution has been given a non-integer value 13.299972848109121.
#   warnings.warn(
# /Users/alerico/opt/anaconda3/lib/python3.8/site-packages/scipy/stats/_continuous_distns.py:2958: RuntimeWarning: The shape parameter of the erlang distribution has been given a non-integer value 12.665574660822582.
#   warnings.warn(
# /Users/alerico/opt/anaconda3/lib/python3.8/site-packages/scipy/stats/_continuous_distns.py:2958: RuntimeWarning: The shape parameter of the erlang distribution has been given a non-integer value 12.228382396771437.
#   warnings.warn(
# /Users/alerico/opt/anaconda3/lib/python3.8/site-packages/scipy/stats/_continuous_distns.py:2958: RuntimeWarning: The shape parameter of the erlang distribution has been given a non-integer value 12.619492781395614.
#   warnings.warn(
# /Users/alerico/opt/anaconda3/lib/python3.8/site-packages/scipy/stats/_continuous_distns.py:2958: RuntimeWarning: The shape parameter of the erlang distribution has been given a non-integer value 12.320311919423354.
#   warnings.warn(
# /Users/alerico/opt/anaconda3/lib/python3.8/site-packages/scipy/stats/_continuous_distns.py:2958: RuntimeWarning: The shape parameter of the erlang distribution has been given a non-integer value 12.649711095614677.
#   warnings.warn(
# /Users/alerico/opt/anaconda3/lib/python3.8/site-packages/scipy/stats/_continuous_distns.py:2958: RuntimeWarning: The shape parameter of the erlang distribution has been given a non-integer value 12.554213402201022.
#   warnings.warn(
# /Users/alerico/opt/anaconda3/lib/python3.8/site-packages/scipy/stats/_continuous_distns.py:2958: RuntimeWarning: The shape parameter of the erlang distribution has been given a non-integer value 11.77699353479225.
#   warnings.warn(
# /Users/alerico/opt/anaconda3/lib/python3.8/site-packages/scipy/stats/_continuous_distns.py:2958: RuntimeWarning: The shape parameter of the erlang distribution has been given a non-integer value 11.76877124345517.
#   warnings.warn(
# /Users/alerico/opt/anaconda3/lib/python3.8/site-packages/scipy/stats/_continuous_distns.py:2958: RuntimeWarning: The shape parameter of the erlang distribution has been given a non-integer value 11.320369534771466.
#   warnings.warn(
# /Users/alerico/opt/anaconda3/lib/python3.8/site-packages/scipy/stats/_continuous_distns.py:2958: RuntimeWarning: The shape parameter of the erlang distribution has been given a non-integer value 12.651870841927447.
#   warnings.warn(
# /Users/alerico/opt/anaconda3/lib/python3.8/site-packages/scipy/stats/_continuous_distns.py:2958: RuntimeWarning: The shape parameter of the erlang distribution has been given a non-integer value 12.329591738965739.
#   warnings.warn(
# /Users/alerico/opt/anaconda3/lib/python3.8/site-packages/scipy/stats/_continuous_distns.py:2958: RuntimeWarning: The shape parameter of the erlang distribution has been given a non-integer value 11.945942480697884.
#   warnings.warn(
# /Users/alerico/opt/anaconda3/lib/python3.8/site-packages/scipy/stats/_continuous_distns.py:2958: RuntimeWarning: The shape parameter of the erlang distribution has been given a non-integer value 11.641807019946313.
#   warnings.warn(
# /Users/alerico/opt/anaconda3/lib/python3.8/site-packages/scipy/stats/_continuous_distns.py:2958: RuntimeWarning: The shape parameter of the erlang distribution has been given a non-integer value 11.712040997920216.
#   warnings.warn(
# /Users/alerico/opt/anaconda3/lib/python3.8/site-packages/scipy/stats/_continuous_distns.py:2958: RuntimeWarning: The shape parameter of the erlang distribution has been given a non-integer value 12.175204053704359.
#   warnings.warn(
# /Users/alerico/opt/anaconda3/lib/python3.8/site-packages/scipy/stats/_continuous_distns.py:2958: RuntimeWarning: The shape parameter of the erlang distribution has been given a non-integer value 11.07198403614311.
#   warnings.warn(
# /Users/alerico/opt/anaconda3/lib/python3.8/site-packages/scipy/stats/_continuous_distns.py:2958: RuntimeWarning: The shape parameter of the erlang distribution has been given a non-integer value 11.490558829740685.
#   warnings.warn(
# /Users/alerico/opt/anaconda3/lib/python3.8/site-packages/scipy/stats/_continuous_distns.py:2958: RuntimeWarning: The shape parameter of the erlang distribution has been given a non-integer value 11.351452622883443.
#   warnings.warn(
# /Users/alerico/opt/anaconda3/lib/python3.8/site-packages/scipy/stats/_continuous_distns.py:2958: RuntimeWarning: The shape parameter of the erlang distribution has been given a non-integer value 12.37365842821297.
#   warnings.warn(
# /Users/alerico/opt/anaconda3/lib/python3.8/site-packages/scipy/stats/_continuous_distns.py:2958: RuntimeWarning: The shape parameter of the erlang distribution has been given a non-integer value 11.397402634160574.
#   warnings.warn(
# /Users/alerico/opt/anaconda3/lib/python3.8/site-packages/scipy/stats/_continuous_distns.py:2958: RuntimeWarning: The shape parameter of the erlang distribution has been given a non-integer value 10.751904130955857.
#   warnings.warn(
# /Users/alerico/opt/anaconda3/lib/python3.8/site-packages/scipy/stats/_continuous_distns.py:2958: RuntimeWarning: The shape parameter of the erlang distribution has been given a non-integer value 11.107729111642984.
#   warnings.warn(
# /Users/alerico/opt/anaconda3/lib/python3.8/site-packages/scipy/stats/_continuous_distns.py:2958: RuntimeWarning: The shape parameter of the erlang distribution has been given a non-integer value 10.929249225845016.
#   warnings.warn(
# /Users/alerico/opt/anaconda3/lib/python3.8/site-packages/scipy/stats/_continuous_distns.py:2958: RuntimeWarning: The shape parameter of the erlang distribution has been given a non-integer value 10.57297032879437.
#   warnings.warn(
# /Users/alerico/opt/anaconda3/lib/python3.8/site-packages/scipy/stats/_continuous_distns.py:2958: RuntimeWarning: The shape parameter of the erlang distribution has been given a non-integer value array(10.57297033).
#   warnings.warn(
# dweibull: statistic=0.12149655103953251, pvalue=0.8795377316926981
# dgamma: statistic=0.13436559573863116, pvalue=0.7953924579436651
# crystalball: statistic=0.1547505184672477, pvalue=0.6406074226893834
# exponnorm: statistic=0.1547577881924977, pvalue=0.6405506868792415
# cosine: statistic=0.16894533295879074, pvalue=0.5316216852969093
# erlang: statistic=0.17026618649472725, pvalue=0.5217983355045706
# chi: statistic=0.1855078024674669, pvalue=0.4147022534032516
# exponpow: statistic=0.18563089521954013, pvalue=0.4138902589898835
# expon: statistic=0.1955445409024038, pvalue=0.35159979309111855
# chi2: statistic=0.24055104868687271, pvalue=0.14873933163832065

# %% [markdown]
# >Las distribuciones de probabilidad que mejor se ajustan a nuestros datos, según la prueba de Kolmogorov son:
# >- **DWEIBULL**
# >- **DGAMMA**
# >- **CRYSTALBALL**
#
# > Utilizaremos el método **Q-Q** para las mejores distribuciones de probabilidad para nuestro conjunto de datos.

# %% [markdown]
# ### DWEIBULL

# %%
qq(prom_CT2,"dweibull")

# %% [markdown]
# ### DGAMMA

# %%
qq(prom_CT2,"dgamma")

# %% [markdown]
# ### CRYSTALBALL

# %%
qq(prom_CT2,"crystalball")

# %% [markdown]
# > La distribución de probabilidad que mejor se ajusta a nuestros datos es **DWEIBULL** donde podemos ver que el punto de en medio es donde los datos son más ajustados y entre más alejados de esto (las colas) son más alejadas.

# %% [markdown]
# ## Parámetros

# %%
params = st.dweibull.fit(prom_CT2)
# Separate parts of parameters
arg = params[:-2]
loc2 = params[-2]
scale2 = params[-1]

c = arg[0]

print('c=',c,'loc=',loc2,'scale=',scale2)
# Out:
# c= 2.1623208085265477 loc= 0.8196923047708111 scale= 0.6586773572088682

# %% [markdown]
# ## Intervalo de confianza

# %%
np.random.seed(55555)
#media = 10; sd = 20
N = 100
confianza = 0.95
X = dweibull.rvs(c,loc2,scale2,N)
st.sem
i1 = st.t.interval(confianza,len(X)-1, loc=np.mean(X), scale=st.sem(X))
print('Con una confianza de %2.2f la media estará en el intervalo t,\n %s' %(confianza,i1))
print('Media calculada' ,np.mean(X))
# Out:
# Con una confianza de 0.95 la media estará en el intervalo t,
#  (0.7018508784903912, 0.9521947304894043)
# Media calculada 0.8270228044898977

# %% [markdown]
# ## Prueba chi cuadrada - Histograma

# %%
np.random.seed(555)
mu_real = prom_CT2.mean()
sigma_real = prom_CT2.std()
N = 100 # Cantidad de muestras
n1 = st.dweibull.rvs(c,loc2,scale2, size=1000)
J = 90  # Cantidad de particiones del histograma
plt.figure(figsize=(8,6))
[freq, x, _] = plt.hist(n1, J, density=True,color='orange')
plt.title('Histograma de datos con distribución DWEIBULL',size=13)
plt.show()
# Se obvia el último valor de x para obtener exactamente J muestras de x
x = x[:-1] 

# Media y desviación estándar muestral
mu = np.mean(x)
sigma = np.std(x)
print('media =%f, desviación estándar muestral =%f'%(mu,sigma))
# Out:
# media =0.711427, desviación estándar muestral =0.926053

# %% [markdown]
# ### Prueba de hipótesis
#
# > $H_0$: la distribución es dweibull.
#
# > $H_a$: los datos no se distribuyen dweibull.

# %%
pi = st.dweibull.pdf(x, c,loc2,scale2)
# Cálculo de la esperanza usando la expresión teórica
Ei = x*pi
# Cálculo teórico de la chi cuadrada
x2 = np.sum(list(map(lambda Ei, obs_i:(obs_i - Ei)**2 / Ei, Ei, freq)))
print('Valor de chi cuadrado teorico  = ', x2)

# Cálculo usando la librería estadística de la chi cuadrada
X2 = st.chisquare(freq, Ei)
print('Valor de chi cuadrado librería = ', X2)

# Cálculo de Grados de libertad del estadístico
p = 2 # Parámetros estimados con los datos
m = J-p-1 # grados de libertad

Chi_est = st.chi2.ppf(q=0.95, df=m)
print('Estadístico de chi_cuadrado = ', Chi_est)
print('Media muestral = ', mu, '\nDesviación estándar muestral = ', sigma)
# Out:
# Valor de chi cuadrado teorico  =  18.394324939004058
# Valor de chi cuadrado librería =  Power_divergenceResult(statistic=18.394324939004058, pvalue=1.0)
# Estadístico de chi_cuadrado =  109.77330935028795
# Media muestral =  0.711426800586501
# Desviación estándar muestral =  0.9260530753797328

# %% [markdown]
# > No rechazamos $H_0$ por lo tanto, los datos distribuyen dweibull.

# %% [markdown]
# ## Muestreo estratificado

# %%
N = 500
# (Método transformada inversa visto en clases pasadas)
# Método montecarlo estándar 
montecarlo_standar = st.dweibull.ppf(np.random.rand(N),c)
plt.figure(figsize=(10,8))
plt.hist(montecarlo_standar,120,density=True,color='orange')
plt.title('Montecarlo estándar')
plt.show()

# Método muestreo estratificado (B estratos)
B = N
U2 = np.random.rand(B)
i = np.arange(0,B)
v = (U2+i)/B
m_estratificado = st.dweibull.ppf(v,c)

plt.figure(figsize=(10,8))
plt.hist(m_estratificado,120,density=True,color='gold')
plt.title('Muestreo estratificado')
plt.show()

# %% [markdown]
# > Los datos y la distribución se observan mucho más claros y mejor distribuidas.

# %% [markdown]
# ## Conclusión

# %% [markdown]
# ## Referencias
